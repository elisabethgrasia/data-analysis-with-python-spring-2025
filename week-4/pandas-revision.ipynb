# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nums = [1, 2, 3, 4,5]

s = pd.Series(nums)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
nums = [1, 2, 3, 4, 5]

s = pd.Series(nums, index = ['aa', 'bb', 'cc', 'dd', 'ee'])
print(s)
# Out:
# aa    1
# bb    2
# cc    3
# dd    4
# ee    5
# dtype: int64

# %%
list(s.index)
# Out:
# ['aa', 'bb', 'cc', 'dd', 'ee']

# %%
values = list(s.values)
values
# Out:
# [1, 2, 3, 4, 5]

# %%
fruits = ['Orange','Banana','Mango']
fruits = pd.Series(fruits, index=[1, 2, 3])
print(fruits)
# Out:
# 1    Orange
# 2    Banana
# 3     Mango
# dtype: object

# %%
fruits = ['Orange','Banana','Mango']
fruits = pd.Series(fruits, index=['o', 'b', 'm'])
print(fruits)
# Out:
# o    Orange
# b    Banana
# m     Mango
# dtype: object

# %%
fruits['o']
# Out:
# 'Orange'

# %%
dct = {
    'name':'Asabeneh',
    'country':'Finland',
    'city':'Helsinki'
}
s = pd.Series(dct)
print(s)
# Out:
# name       Asabeneh
# country     Finland
# city       Helsinki
# dtype: object

# %%
s.index
# Out:
# Index(['name', 'country', 'city'], dtype='object')

# %%
s.values
# Out:
# array(['Asabeneh', 'Finland', 'Helsinki'], dtype=object)

# %%
s = pd.Series(10, index = range(100))
print(s)
# Out:
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10
#       ..
# 95    10
# 96    10
# 97    10
# 98    10
# 99    10
# Length: 100, dtype: int64

# %%
len(s)
# Out:
# 100

# %%
s = pd.Series(np.linspace(5, 20, 100)) # linspace(starting, end, items)
print(s)
# Out:
# 0      5.000000
# 1      5.151515
# 2      5.303030
# 3      5.454545
# 4      5.606061
#         ...
# 95    19.393939
# 96    19.545455
# 97    19.696970
# 98    19.848485
# 99    20.000000
# Length: 100, dtype: float64

# %%
nums = [1, 2, 3]
s = pd.Series(nums, index =['A','B','C'])
print(s)
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
s_copy = s.copy()

# %%
s['A']
# Out:
# 1

# %%
s['B']
# Out:
# 2

# %%
s['C']
# Out:
# 3

# %%
s_copy
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
s_copy['A']  = 100
s_copy['B'] = 200
s_copy['C'] = 300

# %%
s_copy
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
s
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
data = [
    ['Asabeneh', 'Finland', 'Helsink'], 
    ['David', 'UK', 'London'],
    ['John', 'Sweden', 'Stockholm']
]


df = pd.DataFrame(data, columns=['Names','Country','City'])
df
# Out:
#       Names  Country       City
# 0  Asabeneh  Finland    Helsink
# 1     David       UK     London
# 2      John   Sweden  Stockholm

# %%
df.index = ['a', 'b', 'c']

# %%
df
# Out:
#       Names  Country       City
# a  Asabeneh  Finland    Helsink
# b     David       UK     London
# c      John   Sweden  Stockholm

# %%
df.loc['b']
# Out:
# Names       David
# Country        UK
# City       London
# Name: b, dtype: object

# %%
data = [
    {"Name": "Asabeneh", "Country":"Finland","City":"Helsinki"},
    {"Name": "David", "Country":"UK","City":"London"},
    {"Name": "John", "Country":"Sweden","City":"Stockholm"},
    {"Name": "Eyob", "Country":"Finland","City":"Espoo"},
    {"Name": "Pawel", "Country":"Poland","City":"Warsaw"},
    {"Name": "Mahlet", "Country":"Ethiopia","City":"Addis Ababa"},
    {"Name": "Thomas", "Country":"Ethiopia","City":"Bahir Dar"},
    {"Name": "Lidiya", "Country":float('NaN'),"City":float('NaN')},
]
df = pd.DataFrame(data)
df
# Out:
#        Name   Country         City
# 0  Asabeneh   Finland     Helsinki
# 1     David        UK       London
# 2      John    Sweden    Stockholm
# 3      Eyob   Finland        Espoo
# 4     Pawel    Poland       Warsaw
# 5    Mahlet  Ethiopia  Addis Ababa
# 6    Thomas  Ethiopia    Bahir Dar
# 7    Lidiya       NaN          NaN

# %%
df['Name']
# Out:
# 0    Asabeneh
# 1       David
# 2        John
# 3        Eyob
# 4       Pawel
# 5      Mahlet
# 6      Thomas
# 7      Lidiya
# Name: Name, dtype: object

# %%
df['Country']
# Out:
# 0     Finland
# 1          UK
# 2      Sweden
# 3     Finland
# 4      Poland
# 5    Ethiopia
# 6    Ethiopia
# 7         NaN
# Name: Country, dtype: object

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df['City']
# Out:
# 0       Helsinki
# 1         London
# 2      Stockholm
# 3          Espoo
# 4         Warsaw
# 5    Addis Ababa
# 6      Bahir Dar
# 7            NaN
# Name: City, dtype: object

# %%
df['Weight']  = [74, 78, 68, 108, 102, 58, 52, float('NaN')]

# %%
df
# Out:
#        Name   Country         City  Weight
# 0  Asabeneh   Finland     Helsinki    74.0
# 1     David        UK       London    78.0
# 2      John    Sweden    Stockholm    68.0
# 3      Eyob   Finland        Espoo   108.0
# 4     Pawel    Poland       Warsaw   102.0
# 5    Mahlet  Ethiopia  Addis Ababa    58.0
# 6    Thomas  Ethiopia    Bahir Dar    52.0
# 7    Lidiya       NaN          NaN     NaN

# %%
heights = [173, 175, 169, 173, 195,168, 170, float('NaN')]
df['Height'] = heights

# %%
df
# Out:
#        Name   Country         City  Weight  Height
# 0  Asabeneh   Finland     Helsinki    74.0   173.0
# 1     David        UK       London    78.0   175.0
# 2      John    Sweden    Stockholm    68.0   169.0
# 3      Eyob   Finland        Espoo   108.0   173.0
# 4     Pawel    Poland       Warsaw   102.0   195.0
# 5    Mahlet  Ethiopia  Addis Ababa    58.0   168.0
# 6    Thomas  Ethiopia    Bahir Dar    52.0   170.0
# 7    Lidiya       NaN          NaN     NaN     NaN

# %%
df['Height'] = df['Height'] * 0.01

# %%
df
# Out:
#        Name   Country         City  Weight  Height
# 0  Asabeneh   Finland     Helsinki    74.0    1.73
# 1     David        UK       London    78.0    1.75
# 2      John    Sweden    Stockholm    68.0    1.69
# 3      Eyob   Finland        Espoo   108.0    1.73
# 4     Pawel    Poland       Warsaw   102.0    1.95
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70
# 7    Lidiya       NaN          NaN     NaN     NaN

# %%
df.columns
# Out:
# Index(['Name', 'Country', 'City', 'Weight', 'Height'], dtype='object')

# %%
columns = list(df.columns)
columns
# Out:
# ['Name', 'Country', 'City', 'Weight', 'Height']

# %%
df.shape
# Out:
# (8, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     8 non-null      object
#  1   Country  7 non-null      object
#  2   City     7 non-null      object
#  3   Weight   7 non-null      float64
#  4   Height   7 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 452.0+ bytes

# %%
def calculate_bmi():
    weight = df['Weight']
    heigth = df['Height']
    bmi = []
    for w,h in zip(weight, heigth):
        bmi.append(round(w / h ** 2, 1))
    return bmi

# %%
calculate_bmi()
# Out:
# [24.7, 25.5, 23.8, 36.1, 26.8, 20.5, 18.0, nan]

# %%
df['BMI'] = calculate_bmi()

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7
# 1     David        UK       London    78.0    1.75  25.5
# 2      John    Sweden    Stockholm    68.0    1.69  23.8
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0
# 7    Lidiya       NaN          NaN     NaN     NaN   NaN

# %%
## Pandas common methods
"""
- Reading data - loading data
- df.shape
- df.head()
- df.tail()
- df.describe()


"""
# Out:
# '\n- Reading data - loading data\n- df.shape\n- df.head()\n- df.tail()\n- df.describe()\n\n\n'

# %%
df.shape
# Out:
# (8, 6)

# %%
df.head()
# Out:
#        Name  Country       City  Weight  Height   BMI
# 0  Asabeneh  Finland   Helsinki    74.0    1.73  24.7
# 1     David       UK     London    78.0    1.75  25.5
# 2      John   Sweden  Stockholm    68.0    1.69  23.8
# 3      Eyob  Finland      Espoo   108.0    1.73  36.1
# 4     Pawel   Poland     Warsaw   102.0    1.95  26.8

# %%
df.tail()
# Out:
#      Name   Country         City  Weight  Height   BMI
# 3    Eyob   Finland        Espoo   108.0    1.73  36.1
# 4   Pawel    Poland       Warsaw   102.0    1.95  26.8
# 5  Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5
# 6  Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0
# 7  Lidiya       NaN          NaN     NaN     NaN   NaN

# %%
df.describe()
# Out:
#            Weight    Height        BMI
# count    7.000000  7.000000   7.000000
# mean    77.142857  1.747143  25.057143
# std     21.066787  0.092864   5.736682
# min     52.000000  1.680000  18.000000
# 25%     63.000000  1.695000  22.150000
# 50%     74.000000  1.730000  24.700000
# 75%     90.000000  1.740000  26.150000
# max    108.000000  1.950000  36.100000

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7
# 1     David        UK       London    78.0    1.75  25.5
# 2      John    Sweden    Stockholm    68.0    1.69  23.8
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0
# 7    Lidiya       NaN          NaN     NaN     NaN   NaN

# %%
birth_year = ['1769', '1985', '1990', '1983', '1985','1995', '1999', float('NaN')]

# %%
df['Birth Year'] = birth_year
now = datetime.now()
year = now.year
df['Current Year'] = year

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    Lidiya       NaN          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 0          2025
# 1          2025
# 2          2025
# 3          2025
# 4          2025
# 5          2025
# 6          2025
# 7          2025

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    Lidiya       NaN          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 0          2025
# 1          2025
# 2          2025
# 3          2025
# 4          2025
# 5          2025
# 6          2025
# 7          2025

# %%
df_copy.drop('Name', axis = 1, inplace=True)

# %%
df_copy
# Out:
#     Country         City  Weight  Height   BMI Birth Year  Current Year
# 0   Finland     Helsinki    74.0    1.73  24.7       1769          2025
# 1        UK       London    78.0    1.75  25.5       1985          2025
# 2    Sweden    Stockholm    68.0    1.69  23.8       1990          2025
# 3   Finland        Espoo   108.0    1.73  36.1       1983          2025
# 4    Poland       Warsaw   102.0    1.95  26.8       1985          2025
# 5  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995          2025
# 6  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999          2025
# 7       NaN          NaN     NaN     NaN   NaN        NaN          2025

# %%
df_copy.drop(['Country', 'City'], axis = 1, inplace=True)

# %%
df_copy
# Out:
#    Weight  Height   BMI Birth Year  Current Year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025
# 7     NaN     NaN   NaN        NaN          2025

# %%
df_copy.drop(['Birth Year', 'Current Year'], axis = 1)
# Out:
#    Weight  Height   BMI
# 0    74.0    1.73  24.7
# 1    78.0    1.75  25.5
# 2    68.0    1.69  23.8
# 3   108.0    1.73  36.1
# 4   102.0    1.95  26.8
# 5    58.0    1.68  20.5
# 6    52.0    1.70  18.0
# 7     NaN     NaN   NaN

# %%
# df_copy.dropna(inplace=True)

# %%
df_copy
# Out:
#    Weight  Height   BMI Birth Year  Current Year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025
# 7     NaN     NaN   NaN        NaN          2025

# %%
df_copy.to_json('weight-height-bmi.json', index = False)

# %%
# Removing rows

# %%
df_copy
# Out:
#    Weight  Height   BMI Birth Year  Current Year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025
# 7     NaN     NaN   NaN        NaN          2025

# %%
df.drop(range(1, 8, 2), axis = 0)
# Out:
#        Name   Country       City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland   Helsinki    74.0    1.73  24.7       1769
# 2      John    Sweden  Stockholm    68.0    1.69  23.8       1990
# 4     Pawel    Poland     Warsaw   102.0    1.95  26.8       1985
# 6    Thomas  Ethiopia  Bahir Dar    52.0    1.70  18.0       1999
#
#    Current Year
# 0          2025
# 2          2025
# 4          2025
# 6          2025

# %%
df.drop(range(0, 8, 2), axis = 0)
# Out:
#      Name   Country         City  Weight  Height   BMI Birth Year  \
# 1   David        UK       London    78.0    1.75  25.5       1985
# 3    Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 5  Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 7  Lidiya       NaN          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 1          2025
# 3          2025
# 5          2025
# 7          2025

# %%
df_copy
# Out:
#    Weight  Height   BMI Birth Year  Current Year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025
# 7     NaN     NaN   NaN        NaN          2025

# %%
df.columns
# Out:
# Index(['Name', 'Country', 'City', 'Weight', 'Height', 'BMI', 'Birth Year',
#        'Current Year'],
#       dtype='object')

# %%
# df_copy.columns = ['weight', 'height', 'bmi', 'birth_year', 'current_year']

# %%
df_copy
# Out:
#    Weight  Height   BMI Birth Year  Current Year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025
# 7     NaN     NaN   NaN        NaN          2025

# %%
# To modifiy original dataframe the inplace=True should be included
df.rename(
    columns={
        "Name":"name",
        "Country": "country",
        "City": "city",
        "Weight":"weight",
        "Height":"height",
        "BMI":'bmi',
        'Birth Year':'birth_year',
        'Current Year':'current_year'
    }
)
# Out:
#        name   country         city  weight  height   bmi birth_year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    Lidiya       NaN          NaN     NaN     NaN   NaN        NaN
#
#    current_year
# 0          2025
# 1          2025
# 2          2025
# 3          2025
# 4          2025
# 5          2025
# 6          2025
# 7          2025

# %%
df_copy
# Out:
#    Weight  Height   BMI Birth Year  Current Year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025
# 7     NaN     NaN   NaN        NaN          2025

# %%
df_copy.rename(columns = str.lower, inplace=True)

# %%
df_copy['birth year'].dtype
# Out:
# dtype('O')

# %%
df_copy.dropna(inplace=True)

# %%
df_copy
# Out:
#    weight  height   bmi birth year  current year
# 0    74.0    1.73  24.7       1769          2025
# 1    78.0    1.75  25.5       1985          2025
# 2    68.0    1.69  23.8       1990          2025
# 3   108.0    1.73  36.1       1983          2025
# 4   102.0    1.95  26.8       1985          2025
# 5    58.0    1.68  20.5       1995          2025
# 6    52.0    1.70  18.0       1999          2025

# %%
df_copy['birth year'] = df_copy['birth year'].astype('int')

# %%
df_copy
# Out:
#    weight  height   bmi  birth year  current year
# 0    74.0    1.73  24.7        1769          2025
# 1    78.0    1.75  25.5        1985          2025
# 2    68.0    1.69  23.8        1990          2025
# 3   108.0    1.73  36.1        1983          2025
# 4   102.0    1.95  26.8        1985          2025
# 5    58.0    1.68  20.5        1995          2025
# 6    52.0    1.70  18.0        1999          2025

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    Lidiya       NaN          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 0          2025
# 1          2025
# 2          2025
# 3          2025
# 4          2025
# 5          2025
# 6          2025
# 7          2025

# %%
df_back= df.copy()

# %%
df.dropna(inplace=True)

# %%
ages = df['Current Year'].astype('int') - df['Birth Year'].astype('int')
ages
# Out:
# 0    256
# 1     40
# 2     35
# 3     42
# 4     40
# 5     30
# 6     26
# dtype: int32

# %%
df['Age'] = ages

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
#
#    Current Year  Age
# 0          2025  256
# 1          2025   40
# 2          2025   35
# 3          2025   42
# 4          2025   40
# 5          2025   30
# 6          2025   26

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
#
#    Current Year  Age
# 0          2025  256
# 1          2025   40
# 2          2025   35
# 3          2025   42
# 4          2025   40
# 5          2025   30
# 6          2025   26

# %%
average_age = sum(df[1:]['Age'])/len(df[1:]['Age'])
print(average_age)
# Out:
# 35.5

# %%
df.loc[0, 'Age'] = round(average_age)

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
#
#    Current Year  Age
# 0          2025   36
# 1          2025   40
# 2          2025   35
# 3          2025   42
# 4          2025   40
# 5          2025   30
# 6          2025   26

# %%
df.to_csv('person.csv', index=False)

# %%
# selecting columns
df['Name']
# Out:
# 0    Asabeneh
# 1       David
# 2        John
# 3        Eyob
# 4       Pawel
# 5      Mahlet
# 6      Thomas
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    36
# 1    40
# 2    35
# 3    42
# 4    40
# 5    30
# 6    26
# Name: Age, dtype: int32

# %%
df[['Name','Country', 'City']]
# Out:
#        Name   Country         City
# 0  Asabeneh   Finland     Helsinki
# 1     David        UK       London
# 2      John    Sweden    Stockholm
# 3      Eyob   Finland        Espoo
# 4     Pawel    Poland       Warsaw
# 5    Mahlet  Ethiopia  Addis Ababa
# 6    Thomas  Ethiopia    Bahir Dar

# %%
df[['Name','Country', 'City']].to_csv('countries.csv')

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
#
#    Current Year  Age
# 0          2025   36
# 1          2025   40
# 2          2025   35
# 3          2025   42
# 4          2025   40
# 5          2025   30
# 6          2025   26

# %%
df['Birth Year'] = df['Birth Year'].astype('int')

# %%
df[df['Birth Year'] < 1900]
# Out:
#        Name  Country      City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh  Finland  Helsinki    74.0    1.73  24.7        1769
#
#    Current Year  Age
# 0          2025   36

# %%
# BMI if BMI is 18.5 to 25, it is a healthy weight 
df[(df['BMI'] <= 25) & (df['BMI'] >= 18.5) ]
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
#
#    Current Year  Age
# 0          2025   36
# 2          2025   35
# 5          2025   30

# %%
def classify_bmi(bmi):
    if bmi >= 30:
        return 'Obesity Range'
    elif bmi < 30 and bmi > 25:
        return 'Overweight Range'
    elif bmi < 25 and bmi >= 18.5:
        return 'Healthy Range'
    elif bmi < 18.5:
        return 'Underweight Range'

# %%
df['BMI class'] = df['BMI'].apply(lambda x : classify_bmi(x))

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
# Accessing rows:

# %%
df.loc[range(0, 7, 2)]
# Out:
#        Name   Country       City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland   Helsinki    74.0    1.73  24.7        1769
# 2      John    Sweden  Stockholm    68.0    1.69  23.8        1990
# 4     Pawel    Poland     Warsaw   102.0    1.95  26.8        1985
# 6    Thomas  Ethiopia  Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 2          2025   35      Healthy Range
# 4          2025   40   Overweight Range
# 6          2025   26  Underweight Range

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.loc[2:5]
# Out:
#      Name   Country         City  Weight  Height   BMI  Birth Year  \
# 2    John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3    Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4   Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5  Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
#
#    Current Year  Age         BMI class
# 2          2025   35     Healthy Range
# 3          2025   42     Obesity Range
# 4          2025   40  Overweight Range
# 5          2025   30     Healthy Range

# %%
df.loc[0, 'Age']
# Out:
# 36

# %%
df.loc[:]
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.iloc[:]
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.iloc[lambda x: x.index % 2 == 0]
# Out:
#        Name   Country       City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland   Helsinki    74.0    1.73  24.7        1769
# 2      John    Sweden  Stockholm    68.0    1.69  23.8        1990
# 4     Pawel    Poland     Warsaw   102.0    1.95  26.8        1985
# 6    Thomas  Ethiopia  Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 2          2025   35      Healthy Range
# 4          2025   40   Overweight Range
# 6          2025   26  Underweight Range

# %%
df.iloc[lambda x: x.index % 2 != 0]
# Out:
#      Name   Country         City  Weight  Height   BMI  Birth Year  \
# 1   David        UK       London    78.0    1.75  25.5        1985
# 3    Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 5  Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
#
#    Current Year  Age         BMI class
# 1          2025   40  Overweight Range
# 3          2025   42     Obesity Range
# 5          2025   30     Healthy Range

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.iloc[0, 0]
# Out:
# 'Asabeneh'

# %%
df.iloc[2:7, 1:4]
# Out:
#     Country         City  Weight
# 2    Sweden    Stockholm    68.0
# 3   Finland        Espoo   108.0
# 4    Poland       Warsaw   102.0
# 5  Ethiopia  Addis Ababa    58.0
# 6  Ethiopia    Bahir Dar    52.0

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df_merged = pd.concat([df, df, df, df])

# %%
df_merged
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# ...

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df_back
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    Lidiya    Filand          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 0          2025
# 1          2025
# 2          2025
# 3          2025
# 4          2025
# 5          2025
# 6          2025
# 7          2025

# %%
df_back['Country'].fillna('Filand', inplace=True)

# %%
df_back
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 7    Lidiya    Filand          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 0          2025
# 1          2025
# 2          2025
# 3          2025
# 4          2025
# 5          2025
# 6          2025
# 7          2025

# %%
round(df.iloc[1:]['Birth Year'].mean())
# Out:
# 1990

# %%
df_merged
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# ...

# %%
df_merged.shape
# Out:
# (28, 10)

# %%
df_merged.drop_duplicates(inplace=True)

# %%
df_merged
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df_merged.shape
# Out:
# (7, 10)

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.describe(include='all')
# Out:
#             Name  Country      City      Weight    Height        BMI  \
# count          7        7         7    7.000000  7.000000   7.000000
# unique         7        5         7         NaN       NaN        NaN
# top     Asabeneh  Finland  Helsinki         NaN       NaN        NaN
# freq           1        2         1         NaN       NaN        NaN
# mean         NaN      NaN       NaN   77.142857  1.747143  25.057143
# std          NaN      NaN       NaN   21.066787  0.092864   5.736682
# min          NaN      NaN       NaN   52.000000  1.680000  18.000000
# 25%          NaN      NaN       NaN   63.000000  1.695000  22.150000
# 50%          NaN      NaN       NaN   74.000000  1.730000  24.700000
# 75%          NaN      NaN       NaN   90.000000  1.740000  26.150000
# max          NaN      NaN       NaN  108.000000  1.950000  36.100000
#
#          Birth Year  Current Year        Age      BMI class
# count      7.000000           7.0   7.000000              7
# ...

# %%
df.describe()
# Out:
#            Weight    Height        BMI   Birth Year  Current Year        Age
# count    7.000000  7.000000   7.000000     7.000000           7.0   7.000000
# mean    77.142857  1.747143  25.057143  1958.000000        2025.0  35.571429
# std     21.066787  0.092864   5.736682    83.544399           0.0   5.826867
# min     52.000000  1.680000  18.000000  1769.000000        2025.0  26.000000
# 25%     63.000000  1.695000  22.150000  1984.000000        2025.0  32.500000
# 50%     74.000000  1.730000  24.700000  1985.000000        2025.0  36.000000
# 75%     90.000000  1.740000  26.150000  1992.500000        2025.0  40.000000
# max    108.000000  1.950000  36.100000  1999.000000        2025.0  42.000000

# %%
df['Weight'].mean()
# Out:
# 77.14285714285714

# %%
df['Weight'].median()
# Out:
# 74.0

# %%
df['Weight'].min()
# Out:
# 52.0

# %%
df['Weight'].max()
# Out:
# 108.0

# %%
df['Weight'].std()
# Out:
# 21.066787220872666

# %%
df['Weight'].var()
# Out:
# 443.80952380952385

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.groupby('Country').value_counts()
# Out:
# Country   Name      City         Weight  Height  BMI   Birth Year  Current Year  Age  BMI class
# Ethiopia  Mahlet    Addis Ababa  58.0    1.68    20.5  1995        2025          30   Healthy Range        1
#           Thomas    Bahir Dar    52.0    1.70    18.0  1999        2025          26   Underweight Range    1
# Finland   Asabeneh  Helsinki     74.0    1.73    24.7  1769        2025          36   Healthy Range        1
#           Eyob      Espoo        108.0   1.73    36.1  1983        2025          42   Obesity Range        1
# Poland    Pawel     Warsaw       102.0   1.95    26.8  1985        2025          40   Overweight Range     1
# Sweden    John      Stockholm    68.0    1.69    23.8  1990        2025          35   Healthy Range        1
# UK        David     London       78.0    1.75    25.5  1985        2025          40   Overweight Range     1
# Name: count, dtype: int64

# %%
df.sort_values(['Name', 'Country'], ascending=True)
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 3          2025   42      Obesity Range
# 2          2025   35      Healthy Range
# 5          2025   30      Healthy Range
# 4          2025   40   Overweight Range
# 6          2025   26  Underweight Range

# %%
df_back.sort_values('City', na_position='last')
# Out:
#        Name   Country         City  Weight  Height   BMI Birth Year  \
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5       1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0       1999
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1       1983
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7       1769
# 1     David        UK       London    78.0    1.75  25.5       1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8       1990
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8       1985
# 7    Lidiya    Filand          NaN     NaN     NaN   NaN        NaN
#
#    Current Year
# 5          2025
# 6          2025
# 3          2025
# 0          2025
# 1          2025
# 2          2025
# 4          2025
# 7          2025

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 1     David        UK       London    78.0    1.75  25.5        1985
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 1          2025   40   Overweight Range
# 2          2025   35      Healthy Range
# 3          2025   42      Obesity Range
# 4          2025   40   Overweight Range
# 5          2025   30      Healthy Range
# 6          2025   26  Underweight Range

# %%
df.sort_values('BMI class', key=lambda col: col.str.lower(), inplace=True)

# %%
df
# Out:
#        Name   Country         City  Weight  Height   BMI  Birth Year  \
# 0  Asabeneh   Finland     Helsinki    74.0    1.73  24.7        1769
# 2      John    Sweden    Stockholm    68.0    1.69  23.8        1990
# 5    Mahlet  Ethiopia  Addis Ababa    58.0    1.68  20.5        1995
# 3      Eyob   Finland        Espoo   108.0    1.73  36.1        1983
# 1     David        UK       London    78.0    1.75  25.5        1985
# 4     Pawel    Poland       Warsaw   102.0    1.95  26.8        1985
# 6    Thomas  Ethiopia    Bahir Dar    52.0    1.70  18.0        1999
#
#    Current Year  Age          BMI class
# 0          2025   36      Healthy Range
# 2          2025   35      Healthy Range
# 5          2025   30      Healthy Range
# 3          2025   42      Obesity Range
# 1          2025   40   Overweight Range
# 4          2025   40   Overweight Range
# 6          2025   26  Underweight Range

# %%
"""
- Use different data sets
- Time series data
- Text analytics
- Data use for machne learning - Regression and classification
"""
# Out:
# '\n- Use different data sets\n- Time series data\n- Text analytics\n- Data use for machne learning - Regression and classification\n'
