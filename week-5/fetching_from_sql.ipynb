# %%
import mysql.connector as connection
import pandas as pd
def connect_db ():
    try:
        mydb = connection.connect(host="localhost", database = 'school', user="root", passwd="root", use_pure=True)
        query = "Select * from students"
        students_df = pd.read_sql(query, mydb)
        #mydb.close() #close the connection
    except Exception as e:
        # mydb.close()
        print(str(e))

# %%
from sqlalchemy import create_engine
# Replace with your actual credentials
engine = create_engine('mysql+pymysql://root:root@localhost/school')

# %%
students = pd.read_sql("SELECT * FROM Students", engine)
courses = pd.read_sql("SELECT * FROM Courses", engine)
instructors = pd.read_sql("SELECT * FROM instructors", engine)
enrollements = pd.read_sql("SELECT * FROM enrollments", engine)
grades = pd.read_sql("SELECT * FROM grades", engine)

# %%
students
# Out:
#     StudentID StudentName  Age               Email EnrollmentDate  \
# 0           1       Alice   20    alice@school.com     2023-09-01
# 1           2         Bob   21      bob@school.com     2023-09-01
# 2           3     Charlie   19  charlie@school.com     2024-01-15
# 3           4       Diana   22    diana@school.com     2022-09-01
# 4           5         Eve   23      eve@school.com     2023-01-10
# 5           6       Frank   20    frank@school.com     2024-02-01
# 6           7       Grace   21    grace@school.com     2023-09-15
# 7           8       Henry   19    henry@school.com     2024-03-01
# 8           9      Isabel   22   isabel@school.com     2023-08-20
# 9          10        Jack   20     jack@school.com     2024-01-10
# 10         11       Kelly   24    kelly@school.com     2022-08-15
# 11         12        Liam   18     liam@school.com     2024-09-01
# 12         13         Mia   19      mia@school.com     2023-09-10
# ...

# %%
courses
# Out:
#     CourseID   CourseName  Credits  InstructorID   StartDate        Department
# 0        101         Math        3           1.0  2025-01-10       Mathematics
# 1        102      Science        4           2.0  2025-01-10           Science
# 2        103      History        3           3.0  2025-01-15           History
# 3        104          Art        2           4.0  2025-02-01         Fine Arts
# 4        105      Physics        4           5.0  2025-01-20           Physics
# 5        106    Chemistry        3           6.0  2025-01-20           Science
# 6        107  English Lit        3           7.0  2025-02-10           English
# 7        108  Programming        4           8.0  2025-02-15  Computer Science
# 8        109   Psychology        3           9.0  2025-01-25        Psychology
# 9        110    Economics        3          10.0  2025-02-05         Economics
# 10       111    Sociology        3           NaN  2025-03-01         Sociology
# ...

# %%
enrollements
# Out:
#     EnrollmentID  StudentID  CourseID
# 0              1          1       101
# 1              2          1       108
# 2              3          2       102
# 3              4          2       105
# 4              5          3       103
# 5              6          4       104
# 6              7          5       101
# 7              8          5       106
# 8              9          6       105
# 9             10          6       102
# 10            11          7       106
# 11            12          7       102
# 12            13          8       107
# 13            14          9       109
# 14            15          9       107
# 15            16         10       110
# 16            17         10       101
# 17            18         11       111
# 18            19         11       109
# 19            20          3       107
# 20            21         13       108
# 21            22         14       102
# 22            23         15       103
# 23            24         16       104
# ...

# %%
grades
# Out:
#     GradeID  EnrollmentID Grade   GradeDate
# 0         1             1     A  2025-03-15
# 1         2             2    A+  2025-04-01
# 2         3             3    B+  2025-03-20
# 3         4             4     B  2025-03-25
# 4         5             5    A-  2025-03-18
# 5         6             6  None        None
# 6         7             7     B  2025-03-15
# 7         8             8    C+  2025-03-22
# 8         9             9     A  2025-03-25
# 9        10            10    B+  2025-03-20
# 10       11            11    B-  2025-03-22
# 11       12            12  None        None
# 12       13            13  None        None
# 13       14            14     A  2025-03-28
# 14       15            15    B+  2025-04-05
# 15       16            16     B  2025-04-10
# 16       17            17     C  2025-03-15
# 17       18            18    A-  2025-04-15
# 18       19            19     B  2025-03-28
# 19       20            20  None        None
# ...

# %%
instructors
# Out:
#    InstructorID InstructorName              Email        Department  \
# 0             1      Dr. Smith   smith@school.com       Mathematics
# 1             2    Prof. Jones   jones@school.com           Science
# 2             3        Dr. Lee     lee@school.com           History
# 3             4     Ms. Taylor  taylor@school.com         Fine Arts
# 4             5      Dr. Brown   brown@school.com           Physics
# 5             6    Prof. Adams   adams@school.com           Science
# 6             7     Ms. Carter  carter@school.com           English
# 7             8     Mr. Wilson  wilson@school.com  Computer Science
# 8             9      Dr. Evans   evans@school.com        Psychology
# 9            10    Prof. Patel   patel@school.com         Economics
#
#      HireDate
# 0  2018-06-01
# 1  2019-08-15
# 2  2020-01-10
# 3  2021-03-20
# 4  2017-09-01
# 5  2018-11-05
# 6  2022-02-15
# 7  2020-07-01
# 8  2019-04-10
# 9  2021-09-01
