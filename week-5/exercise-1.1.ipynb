# %%
# importing necessary packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from pprint import pprint

# %%
# fetching API data
def format_value(txt):
    lower, highest = txt.split(' - ')
    return (int(lower) + int(highest)) / 2

# %%
# fetching API data
 
url = 'https://api.thecatapi.com/v1/breeds'
response = requests.get(url)
data = response.json()
cats = []
for cat in data:
    average_weight = format_value(cat['weight']['metric'])
    average_life_span = format_value(cat['life_span'])
    reference_image_id = cat.get('reference_image_id')
    image_url =  f'https://cdn2.thecatapi.com/images/{reference_image_id}.jpg' if reference_image_id else ''
    dct = {
        'id':cat['id'],
        'name': cat['name'],
        'origin': cat['origin'],
        'description':cat['description'],
         'weight':average_weight,
        'life_span': average_life_span,
        'temperament':cat['temperament'],
         'image_url': image_url
    }
    cats.append(dct)
pprint(cats[:3])
# Out:
# [{'description': 'The Abyssinian is easy to care for, and a joy to have in '
#                  'your home. They’re affectionate cats and love both people '
#                  'and other animals.',
#   'id': 'abys',
#   'image_url': 'https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg',
#   'life_span': 14.5,
#   'name': 'Abyssinian',
#   'origin': 'Egypt',
#   'temperament': 'Active, Energetic, Independent, Intelligent, Gentle',
#   'weight': 4.0},
#  {'description': 'Native to the Greek islands known as the Cyclades in the '
#                  'Aegean Sea, these are natural cats, meaning they developed '
#                  'without humans getting involved in their breeding. As a '
#                  'breed, Aegean Cats are rare, although they are numerous on '
#                  'their home islands. They are generally friendly toward '
#                  'people and can be excellent cats for families with children.',
#   'id': 'aege',
#   'image_url': 'https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg',
#   'life_span': 10.5,
#   'name': 'Aegean',
#   'origin': 'Greece',
#   'temperament': 'Affectionate, Social, Intelligent, Playful, Active',
#   'weight': 4.0},
#  {'description': 'American Bobtails are loving and incredibly intelligent cats '
#                  'possessing a distinctive wild appearance. They are extremely '
#                  'interactive cats that bond with their human family with '
#                  'great devotion.',
#   'id': 'abob',
#   'image_url': 'https://cdn2.thecatapi.com/images/hBXicehMA.jpg',
#   'life_span': 13.0,
#   'name': 'American Bobtail',
#   'origin': 'United States',
#   'temperament': 'Intelligent, Interactive, Lively, Playful, Sensitive',
#   'weight': 5.0}]

# %%
pd.DataFrame(cats)
# Out:
#       id                  name                origin  \
# 0   abys            Abyssinian                 Egypt
# 1   aege                Aegean                Greece
# 2   abob      American Bobtail         United States
# 3   acur         American Curl         United States
# 4   asho    American Shorthair         United States
# 5   awir     American Wirehair         United States
# 6   amau           Arabian Mau  United Arab Emirates
# 7   amis       Australian Mist             Australia
# 8   bali              Balinese         United States
# 9   bamb               Bambino         United States
# 10  beng                Bengal         United States
# 11  birm                Birman                France
# 12  bomb                Bombay         United States
# 13  bslo      British Longhair        United Kingdom
# 14  bsho     British Shorthair        United Kingdom
# 15  bure               Burmese                 Burma
# 16  buri              Burmilla        United Kingdom
# 17  cspa   California Spangled         United States
# 18  ctif     Chantilly-Tiffany         United States
# 19  char             Chartreux                France
# 20  chau               Chausie                 Egypt
# 21  chee               Cheetoh         United States
# 22  csho  Colorpoint Shorthair         United States
# 23  crex           Cornish Rex        United Kingdom
# 24  cymr                Cymric                Canada
# 25  cypr                Cyprus                Cyprus
# 26  drex             Devon Rex        United Kingdom
# 27  dons               Donskoy                Russia
# 28  lihu             Dragon Li                 China
# 29  emau          Egyptian Mau                 Egypt
# 30  ebur      European Burmese                 Burma
# 31  esho      Exotic Shorthair         United States
# 32  hbro          Havana Brown        United Kingdom
# 33  hima             Himalayan         United States
# 34  jbob      Japanese Bobtail                 Japan
# 35  java              Javanese         United States
# 36  khao            Khao Manee              Thailand
# 37  kora                 Korat              Thailand
# 38  kuri              Kurilian                Russia
# 39  lape                LaPerm              Thailand
# 40  mcoo            Maine Coon         United States
# 41  mala               Malayan        United Kingdom
# 42  manx                  Manx           Isle of Man
# 43  munc              Munchkin         United States
# 44  nebe              Nebelung         United States
# 45  norw  Norwegian Forest Cat                Norway
# 46  ocic                Ocicat         United States
# 47  orie              Oriental         United States
# 48  pers               Persian         Iran (Persia)
# 49  pixi             Pixie-bob         United States
# 50  raga            Ragamuffin         United States
# 51  ragd               Ragdoll         United States
# 52  rblu          Russian Blue                Russia
# 53  sava              Savannah         United States
# 54  sfol         Scottish Fold        United Kingdom
# 55  srex           Selkirk Rex         United States
# 56  siam               Siamese              Thailand
# 57  sibe              Siberian                Russia
# 58  sing             Singapura             Singapore
# 59  snow              Snowshoe         United States
# 60  soma                Somali               Somalia
# 61  sphy                Sphynx                Canada
# 62  tonk             Tonkinese                Canada
# 63  toyg                Toyger         United States
# 64  tang        Turkish Angora                Turkey
# 65  tvan           Turkish Van                Turkey
# 66  ycho        York Chocolate         United States
#
#                                           description  weight  life_span  \
# 0   The Abyssinian is easy to care for, and a joy ...     4.0       14.5
# 1   Native to the Greek islands known as the Cycla...     4.0       10.5
# 2   American Bobtails are loving and incredibly in...     5.0       13.0
# 3   Distinguished by truly unique ears that curl b...     3.5       14.0
# 4   The American Shorthair is known for its longev...     5.5       16.0
# 5   The American Wirehair tends to be a calm and t...     5.5       16.0
# 6   Arabian Mau cats are social and energetic. Due...     5.5       13.0
# 7   The Australian Mist thrives on human companion...     5.0       14.0
# 8   Balinese are curious, outgoing, intelligent ca...     3.5       12.5
# 9   The Bambino is a breed of cat that was created...     3.0       13.0
# 10  Bengals are a lot of fun to live with, but the...     5.0       13.5
# 11  The Birman is a docile, quiet cat who loves pe...     5.0       14.5
# 12  The the golden eyes and the shiny black coa of...     4.0       14.0
# 13  The British Longhair is a very laid-back relax...     6.0       13.0
# 14  The British Shorthair is a very pleasant cat t...     7.0       14.5
# 15  Burmese love being with people, playing with t...     4.0       15.5
# 16  The Burmilla is a fairly placid cat. She tends...     4.5       12.5
# 17  Perhaps the only thing about the California sp...     6.0       12.0
# 18  The Chantilly is a devoted companion and prefe...     4.0       15.0
# 19  The Chartreux is generally silent but communic...     5.0       13.5
# 20  For those owners who desire a feline capable o...     5.0       13.0
# 21  The Cheetoh has a super affectionate nature an...     5.5       13.0
# 22  Colorpoint Shorthairs are an affectionate bree...     3.5       14.0
# 23  This is a confident cat who loves people and w...     3.0       12.5
# 24  The Cymric is a placid, sweet cat. They do not...     5.0       11.0
# 25  Loving, loyal, social and inquisitive, the Cyp...     5.5       13.5
# 26  The favourite perch of the Devon Rex is right ...     3.5       12.5
# 27  Donskoy are affectionate, intelligent, and eas...     5.5       13.5
# 28  The Dragon Li is loyal, but not particularly a...     5.0       13.5
# 29  The Egyptian Mau is gentle and reserved. She l...     4.5       19.0
# 30  The European Burmese is a very affectionate, i...     4.5       12.5
# 31  The Exotic Shorthair is a gentle friendly cat ...     4.5       13.5
# 32  The Havana Brown is human oriented, playful, a...     4.0       12.5
# 33  Calm and devoted, Himalayans make excellent co...     4.5       12.0
# 34  The Japanese Bobtail is an active, sweet, lovi...     3.5       15.0
# 35  Javanese are endlessly interested, intelligent...     3.5       11.0
# 36  The Khao Manee is highly intelligent, with an ...     5.0       11.0
# 37  The Korat is a natural breed, and one of the o...     4.0       12.5
# 38  The character of the Kurilian Bobtail is indep...     5.5       17.5
# 39  LaPerms are gentle and affectionate but also v...     4.0       12.5
# 40  They are known for their size and luxurious lo...     6.5       13.5
# 41  Malayans love to explore and even enjoy travel...     4.5       15.0
# 42  The Manx is a placid, sweet cat that is gentle...     4.5       13.0
# 43  The Munchkin is an outgoing cat who enjoys bei...     3.0       12.5
# 44  The Nebelung may have a reserved nature, but s...     4.0       13.5
# 45  The Norwegian Forest Cat is a sweet, loving ca...     5.5       14.0
# 46  Loyal and devoted to their owners, the Ocicat ...     5.0       13.0
# 47  Orientals are passionate about the people in t...     3.5       13.0
# 48  Persians are sweet, gentle cats that can be pl...     5.0       14.5
# 49  Companionable and affectionate, the Pixie-bob ...     6.0       14.5
# 50  The Ragamuffin is calm, even tempered and gets...     6.5       14.0
# 51  Ragdolls love their people, greeting them at t...     7.0       14.5
# 52  Russian Blues are very loving and reserved. Th...     3.5       13.0
# 53  Savannah is the feline version of a dog. Activ...     7.5       18.5
# 54  The Scottish Fold is a sweet, charming breed. ...     3.5       12.5
# 55  The Selkirk Rex is an incredibly patient, lovi...     5.0       14.5
# 56  While Siamese cats are extremely fond of their...     5.5       13.5
# 57  The Siberians dog like temperament and affecti...     5.5       13.5
# 58  The Singapura is usually cautious when it come...     3.0       13.5
# 59  The Snowshoe is a vibrant, energetic, affectio...     4.0       16.5
# 60  The Somali lives life to the fullest. He climb...     4.0       14.0
# 61  The Sphynx is an intelligent, inquisitive, ext...     4.0       13.0
# 62  Intelligent and generous with their affection,...     4.0       15.0
# 63  The Toyger has a sweet, calm personality and i...     5.0       13.5
# 64  This is a smart and intelligent cat which bond...     3.5       16.5
# 65  While the Turkish Van loves to jump and climb,...     6.0       14.5
# 66  York Chocolate cats are known to be true lap c...     6.5       14.0
#
#                                           temperament  \
# 0   Active, Energetic, Independent, Intelligent, G...
# 1   Affectionate, Social, Intelligent, Playful, Ac...
# 2   Intelligent, Interactive, Lively, Playful, Sen...
# 3   Affectionate, Curious, Intelligent, Interactiv...
# 4          Active, Curious, Easy Going, Playful, Calm
# 5   Affectionate, Curious, Gentle, Intelligent, In...
# 6   Affectionate, Agile, Curious, Independent, Pla...
# 7   Lively, Social, Fun-loving, Relaxed, Affectionate
# 8                  Affectionate, Intelligent, Playful
# 9         Affectionate, Lively, Friendly, Intelligent
# 10    Alert, Agile, Energetic, Demanding, Intelligent
# 11               Affectionate, Active, Gentle, Social
# 12  Affectionate, Dependent, Gentle, Intelligent, ...
# 13  Affectionate, Easy Going, Independent, Intelli...
# 14  Affectionate, Easy Going, Gentle, Loyal, Patie...
# 15  Curious, Intelligent, Gentle, Social, Interact...
# 16  Easy Going, Friendly, Intelligent, Lively, Pla...
# 17  Affectionate, Curious, Intelligent, Loyal, Social
# 18        Affectionate, Demanding, Interactive, Loyal
# 19  Affectionate, Loyal, Intelligent, Social, Live...
# 20         Affectionate, Intelligent, Playful, Social
# 21          Affectionate, Gentle, Intelligent, Social
# 22         Affectionate, Intelligent, Playful, Social
# 23  Affectionate, Intelligent, Active, Curious, Pl...
# 24                Gentle, Loyal, Intelligent, Playful
# 25                               Affectionate, Social
# 26  Highly interactive, Mischievous, Loyal, Social...
# 27               Playful, affectionate, loyal, social
# 28       Intelligent, Friendly, Gentle, Loving, Loyal
# 29  Agile, Dependent, Gentle, Intelligent, Lively,...
# 30                         Sweet, Affectionate, Loyal
# 31        Affectionate, Sweet, Loyal, Quiet, Peaceful
# 32  Affectionate, Curious, Demanding, Friendly, In...
# 33      Dependent, Gentle, Intelligent, Quiet, Social
# 34  Active, Agile, Clever, Easy Going, Intelligent...
# 35              Active, Devoted, Intelligent, Playful
# 36            Calm, Relaxed, Talkative, Playful, Warm
# 37  Active, Loyal, highly intelligent, Expressive,...
# 38  Independent, highly intelligent, clever, inqui...
# 39  Affectionate, Friendly, Gentle, Intelligent, P...
# 40  Adaptable, Intelligent, Loving, Gentle, Indepe...
# 41         Affectionate, Interactive, Playful, Social
# 42    Easy Going, Intelligent, Loyal, Playful, Social
# 43            Agile, Easy Going, Intelligent, Playful
# 44                        Gentle, Quiet, Shy, Playful
# 45  Sweet, Active, Intelligent, Social, Playful, L...
# 46  Active, Agile, Curious, Demanding, Friendly, G...
# 47  Energetic, Affectionate, Intelligent, Social, ...
# 48                 Affectionate, loyal, Sedate, Quiet
# 49           Affectionate, Social, Intelligent, Loyal
# 50               Affectionate, Friendly, Gentle, Calm
# 51   Affectionate, Friendly, Gentle, Quiet, Easygoing
# 52  Active, Dependent, Easy Going, Gentle, Intelli...
# 53  Curious, Social, Intelligent, Loyal, Outgoing,...
# 54  Affectionate, Intelligent, Loyal, Playful, Soc...
# 55  Active, Affectionate, Dependent, Gentle, Patie...
# 56  Active, Agile, Clever, Sociable, Loving, Energ...
# 57  Curious, Intelligent, Loyal, Sweet, Agile, Pla...
# 58  Affectionate, Curious, Easy Going, Intelligent...
# 59  Affectionate, Social, Intelligent, Sweet-tempered
# 60  Mischievous, Tenacious, Intelligent, Affection...
# 61        Loyal, Inquisitive, Friendly, Quiet, Gentle
# 62  Curious, Intelligent, Social, Lively, Outgoing...
# 63                       Playful, Social, Intelligent
# 64  Affectionate, Agile, Clever, Gentle, Intellige...
# 65      Agile, Intelligent, Loyal, Playful, Energetic
# 66    Playful, Social, Intelligent, Curious, Friendly
#
#                                            image_url
# 0    https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
# 1    https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg
# 2    https://cdn2.thecatapi.com/images/hBXicehMA.jpg
# 3    https://cdn2.thecatapi.com/images/xnsqonbjW.jpg
# 4    https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg
# 5    https://cdn2.thecatapi.com/images/8D--jCd21.jpg
# 6    https://cdn2.thecatapi.com/images/k71ULYfRr.jpg
# 7    https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg
# 8    https://cdn2.thecatapi.com/images/13MkvUreZ.jpg
# 9    https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg
# 10   https://cdn2.thecatapi.com/images/O3btzLlsO.jpg
# 11   https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg
# 12   https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg
# 13   https://cdn2.thecatapi.com/images/7isAO4Cav.jpg
# 14   https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg
# 15   https://cdn2.thecatapi.com/images/4lXnnfxac.jpg
# 16   https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg
# 17   https://cdn2.thecatapi.com/images/B1ERTmgph.jpg
# 18   https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg
# 19   https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg
# 20   https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg
# 21   https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg
# 22   https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg
# 23   https://cdn2.thecatapi.com/images/unX21IBVB.jpg
# 24   https://cdn2.thecatapi.com/images/3dbtapCWM.jpg
# 25   https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg
# 26   https://cdn2.thecatapi.com/images/4RzEwvyzz.jpg
# 27   https://cdn2.thecatapi.com/images/3KG57GfMW.jpg
# 28   https://cdn2.thecatapi.com/images/BQMSld0A0.jpg
# 29   https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg
# 30
# 31   https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg
# 32   https://cdn2.thecatapi.com/images/njK25knLH.jpg
# 33   https://cdn2.thecatapi.com/images/CDhOtM-Ig.jpg
# 34   https://cdn2.thecatapi.com/images/-tm9-znzl.jpg
# 35   https://cdn2.thecatapi.com/images/xoI_EpOKe.jpg
# 36   https://cdn2.thecatapi.com/images/165ok6ESN.jpg
# 37   https://cdn2.thecatapi.com/images/DbwiefiaY.jpg
# 38  https://cdn2.thecatapi.com/images/NZpO4pU56M.jpg
# 39   https://cdn2.thecatapi.com/images/aKbsEYjSl.jpg
# 40   https://cdn2.thecatapi.com/images/OOD3VXAQn.jpg
# 41
# 42   https://cdn2.thecatapi.com/images/fhYh2PDcC.jpg
# 43   https://cdn2.thecatapi.com/images/j5cVSqLer.jpg
# 44   https://cdn2.thecatapi.com/images/OGTWqNNOt.jpg
# 45   https://cdn2.thecatapi.com/images/06dgGmEOV.jpg
# 46   https://cdn2.thecatapi.com/images/JAx-08Y0n.jpg
# 47   https://cdn2.thecatapi.com/images/LutjkZJpH.jpg
# 48   https://cdn2.thecatapi.com/images/-Zfz5z2jK.jpg
# 49   https://cdn2.thecatapi.com/images/z7fJRNeN6.jpg
# 50   https://cdn2.thecatapi.com/images/SMuZx-bFM.jpg
# 51   https://cdn2.thecatapi.com/images/oGefY4YoG.jpg
# 52   https://cdn2.thecatapi.com/images/Rhj-JsTLP.jpg
# 53   https://cdn2.thecatapi.com/images/a8nIYvs6S.jpg
# 54   https://cdn2.thecatapi.com/images/o9t0LDcsa.jpg
# 55   https://cdn2.thecatapi.com/images/II9dOZmrw.jpg
# 56   https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg
# 57   https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg
# 58   https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg
# 59   https://cdn2.thecatapi.com/images/MK-sYESvO.jpg
# 60   https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg
# 61   https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg
# 62   https://cdn2.thecatapi.com/images/KBroiVNCM.jpg
# 63   https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg
# 64   https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg
# 65   https://cdn2.thecatapi.com/images/sxIXJax6h.jpg
# 66   https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg

# %%
    
url = 'https://api.thecatapi.com/v1/breeds'
response = requests.get(url)
data = response.json()
cats = []
for cat in data:
    average_weight = format_value(cat['weight']['metric'])
    average_life_span = format_value(cat['life_span'])
    reference_image_id = cat.get('reference_image_id')
    image_url =  f'https://cdn2.thecatapi.com/images/{reference_image_id}.jpg' if reference_image_id else ''
    dct = {
        'ID':cat['id'],
        'Name': cat['name'],
        'Origin': cat['origin'],
        'Description':cat['description'],
        'Weight (kg)':average_weight,
        'Life Span (years)': average_life_span,
        'temperament':cat['temperament'],
         'Image URL': image_url
    }
    cats.append(dct)
pprint(cats)
# Out:
# [{'Description': 'The Abyssinian is easy to care for, and a joy to have in '
#                  'your home. They’re affectionate cats and love both people '
#                  'and other animals.',
#   'ID': 'abys',
#   'Image URL': 'https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Abyssinian',
#   'Origin': 'Egypt',
#   'Weight (kg)': 4.0,
#   'temperament': 'Active, Energetic, Independent, Intelligent, Gentle'},
#  {'Description': 'Native to the Greek islands known as the Cyclades in the '
#                  'Aegean Sea, these are natural cats, meaning they developed '
#                  'without humans getting involved in their breeding. As a '
#                  'breed, Aegean Cats are rare, although they are numerous on '
#                  'their home islands. They are generally friendly toward '
#                  'people and can be excellent cats for families with children.',
#   'ID': 'aege',
#   'Image URL': 'https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg',
#   'Life Span (years)': 10.5,
#   'Name': 'Aegean',
#   'Origin': 'Greece',
#   'Weight (kg)': 4.0,
#   'temperament': 'Affectionate, Social, Intelligent, Playful, Active'},
#  {'Description': 'American Bobtails are loving and incredibly intelligent cats '
#                  'possessing a distinctive wild appearance. They are extremely '
#                  'interactive cats that bond with their human family with '
#                  'great devotion.',
#   'ID': 'abob',
#   'Image URL': 'https://cdn2.thecatapi.com/images/hBXicehMA.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'American Bobtail',
#   'Origin': 'United States',
#   'Weight (kg)': 5.0,
#   'temperament': 'Intelligent, Interactive, Lively, Playful, Sensitive'},
#  {'Description': 'Distinguished by truly unique ears that curl back in a '
#                  'graceful arc, offering an alert, perky, happily surprised '
#                  'expression, they cause people to break out into a big smile '
#                  'when viewing their first Curl. Curls are very '
#                  'people-oriented, faithful, affectionate soulmates, adjusting '
#                  'remarkably fast to other pets, children, and new situations.',
#   'ID': 'acur',
#   'Image URL': 'https://cdn2.thecatapi.com/images/xnsqonbjW.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'American Curl',
#   'Origin': 'United States',
#   'Weight (kg)': 3.5,
#   'temperament': 'Affectionate, Curious, Intelligent, Interactive, Lively, '
#                  'Playful, Social'},
#  {'Description': 'The American Shorthair is known for its longevity, robust '
#                  'health, good looks, sweet personality, and amiability with '
#                  'children, dogs, and other pets.',
#   'ID': 'asho',
#   'Image URL': 'https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg',
#   'Life Span (years)': 16.0,
#   'Name': 'American Shorthair',
#   'Origin': 'United States',
#   'Weight (kg)': 5.5,
#   'temperament': 'Active, Curious, Easy Going, Playful, Calm'},
#  {'Description': 'The American Wirehair tends to be a calm and tolerant cat '
#                  'who takes life as it comes. His favorite hobby is '
#                  'bird-watching from a sunny windowsill, and his hunting '
#                  'ability will stand you in good stead if insects enter the '
#                  'house.',
#   'ID': 'awir',
#   'Image URL': 'https://cdn2.thecatapi.com/images/8D--jCd21.jpg',
#   'Life Span (years)': 16.0,
#   'Name': 'American Wirehair',
#   'Origin': 'United States',
#   'Weight (kg)': 5.5,
#   'temperament': 'Affectionate, Curious, Gentle, Intelligent, Interactive, '
#                  'Lively, Loyal, Playful, Sensible, Social'},
#  {'Description': 'Arabian Mau cats are social and energetic. Due to their '
#                  'energy levels, these cats do best in homes where their '
#                  'owners will be able to provide them with plenty of playtime, '
#                  'attention and interaction from their owners. These kitties '
#                  'are friendly, intelligent, and adaptable, and will even get '
#                  'along well with other pets and children.',
#   'ID': 'amau',
#   'Image URL': 'https://cdn2.thecatapi.com/images/k71ULYfRr.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Arabian Mau',
#   'Origin': 'United Arab Emirates',
#   'Weight (kg)': 5.5,
#   'temperament': 'Affectionate, Agile, Curious, Independent, Playful, Loyal'},
#  {'Description': 'The Australian Mist thrives on human companionship. Tolerant '
#                  'of even the youngest of children, these friendly felines '
#                  'enjoy playing games and being part of the hustle and bustle '
#                  'of a busy household. They make entertaining companions for '
#                  'people of all ages, and are happy to remain indoors between '
#                  'dusk and dawn or to be wholly indoor pets.',
#   'ID': 'amis',
#   'Image URL': 'https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'Australian Mist',
#   'Origin': 'Australia',
#   'Weight (kg)': 5.0,
#   'temperament': 'Lively, Social, Fun-loving, Relaxed, Affectionate'},
#  {'Description': 'Balinese are curious, outgoing, intelligent cats with '
#                  'excellent communication skills. They are known for their '
#                  'chatty personalities and are always eager to tell you their '
#                  'views on life, love, and what you’ve served them for '
#                  'dinner. ',
#   'ID': 'bali',
#   'Image URL': 'https://cdn2.thecatapi.com/images/13MkvUreZ.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Balinese',
#   'Origin': 'United States',
#   'Weight (kg)': 3.5,
#   'temperament': 'Affectionate, Intelligent, Playful'},
#  {'Description': 'The Bambino is a breed of cat that was created as a cross '
#                  'between the Sphynx and the Munchkin breeds. The Bambino cat '
#                  'has short legs, large upright ears, and is usually hairless. '
#                  'They love to be handled and cuddled up on the laps of their '
#                  'family members.',
#   'ID': 'bamb',
#   'Image URL': 'https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Bambino',
#   'Origin': 'United States',
#   'Weight (kg)': 3.0,
#   'temperament': 'Affectionate, Lively, Friendly, Intelligent'},
#  {'Description': "Bengals are a lot of fun to live with, but they're "
#                  'definitely not the cat for everyone, or for first-time cat '
#                  'owners. Extremely intelligent, curious and active, they '
#                  'demand a lot of interaction and woe betide the owner who '
#                  "doesn't provide it.",
#   'ID': 'beng',
#   'Image URL': 'https://cdn2.thecatapi.com/images/O3btzLlsO.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Bengal',
#   'Origin': 'United States',
#   'Weight (kg)': 5.0,
#   'temperament': 'Alert, Agile, Energetic, Demanding, Intelligent'},
#  {'Description': 'The Birman is a docile, quiet cat who loves people and will '
#                  'follow them from room to room. Expect the Birman to want to '
#                  'be involved in what you’re doing. He communicates in a soft '
#                  'voice, mainly to remind you that perhaps it’s time for '
#                  'dinner or maybe for a nice cuddle on the sofa. He enjoys '
#                  'being held and will relax in your arms like a furry baby.',
#   'ID': 'birm',
#   'Image URL': 'https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Birman',
#   'Origin': 'France',
#   'Weight (kg)': 5.0,
#   'temperament': 'Affectionate, Active, Gentle, Social'},
#  {'Description': 'The the golden eyes and the shiny black coa of the Bopmbay '
#                  'is absolutely striking. Likely to bond most with one family '
#                  'member, the Bombay will follow you from room to room and '
#                  'will almost always have something to say about what you are '
#                  'doing, loving attention and to be carried around, often on '
#                  "his caregiver's shoulder.",
#   'ID': 'bomb',
#   'Image URL': 'https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'Bombay',
#   'Origin': 'United States',
#   'Weight (kg)': 4.0,
#   'temperament': 'Affectionate, Dependent, Gentle, Intelligent, Playful'},
#  {'Description': 'The British Longhair is a very laid-back relaxed cat, often '
#                  'perceived to be very independent although they will enjoy '
#                  'the company of an equally relaxed and likeminded cat. They '
#                  'are an affectionate breed, but very much on their own terms '
#                  'and tend to prefer to choose to come and sit with their '
#                  'owners rather than being picked up.',
#   'ID': 'bslo',
#   'Image URL': 'https://cdn2.thecatapi.com/images/7isAO4Cav.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'British Longhair',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 6.0,
#   'temperament': 'Affectionate, Easy Going, Independent, Intelligent, Loyal, '
#                  'Social'},
#  {'Description': 'The British Shorthair is a very pleasant cat to have as a '
#                  'companion, ans is easy going and placid. The British is a '
#                  'fiercely loyal, loving cat and will attach herself to every '
#                  "one of her family members. While loving to play, she doesn't "
#                  'need hourly attention. If she is in the mood to play, she '
#                  'will find someone and bring a toy to that person. The '
#                  'British also plays well by herself, and thus is a good '
#                  'companion for single people.',
#   'ID': 'bsho',
#   'Image URL': 'https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'British Shorthair',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 7.0,
#   'temperament': 'Affectionate, Easy Going, Gentle, Loyal, Patient, calm'},
#  {'Description': 'Burmese love being with people, playing with them, and '
#                  'keeping them entertained. They crave close physical contact '
#                  'and abhor an empty lap. They will follow their humans from '
#                  'room to room, and sleep in bed with them, preferably under '
#                  'the covers, cuddled as close as possible. At play, they will '
#                  'turn around to see if their human is watching and being '
#                  'entertained by their crazy antics.',
#   'ID': 'bure',
#   'Image URL': 'https://cdn2.thecatapi.com/images/4lXnnfxac.jpg',
#   'Life Span (years)': 15.5,
#   'Name': 'Burmese',
#   'Origin': 'Burma',
#   'Weight (kg)': 4.0,
#   'temperament': 'Curious, Intelligent, Gentle, Social, Interactive, Playful, '
#                  'Lively'},
#  {'Description': 'The Burmilla is a fairly placid cat. She tends to be an easy '
#                  'cat to get along with, requiring minimal care. The Burmilla '
#                  'is affectionate and sweet and makes a good companion, the '
#                  'Burmilla is an ideal companion to while away a lonely '
#                  'evening. Loyal, devoted, and affectionate, this cat will '
#                  'stay by its owner, always keeping them company.',
#   'ID': 'buri',
#   'Image URL': 'https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Burmilla',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 4.5,
#   'temperament': 'Easy Going, Friendly, Intelligent, Lively, Playful, Social'},
#  {'Description': 'Perhaps the only thing about the California spangled cat '
#                  'that isn’t wild-like is its personality. Known to be '
#                  'affectionate, gentle and sociable, this breed enjoys '
#                  'spending a great deal of time with its owners. They are very '
#                  'playful, often choosing to perch in high locations and show '
#                  'off their acrobatic skills.',
#   'ID': 'cspa',
#   'Image URL': 'https://cdn2.thecatapi.com/images/B1ERTmgph.jpg',
#   'Life Span (years)': 12.0,
#   'Name': 'California Spangled',
#   'Origin': 'United States',
#   'Weight (kg)': 6.0,
#   'temperament': 'Affectionate, Curious, Intelligent, Loyal, Social'},
#  {'Description': 'The Chantilly is a devoted companion and prefers company to '
#                  'being left alone. While the Chantilly is not demanding, she '
#                  'will "chirp" and "talk" as if having a conversation. This '
#                  'breed is affectionate, with a sweet temperament. It can stay '
#                  'still for extended periods, happily lounging in the lap of '
#                  'its loved one. This quality makes the Tiffany an ideal '
#                  'traveling companion, and an ideal house companion for senior '
#                  'citizens and the physically handicapped.',
#   'ID': 'ctif',
#   'Image URL': 'https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg',
#   'Life Span (years)': 15.0,
#   'Name': 'Chantilly-Tiffany',
#   'Origin': 'United States',
#   'Weight (kg)': 4.0,
#   'temperament': 'Affectionate, Demanding, Interactive, Loyal'},
#  {'Description': 'The Chartreux is generally silent but communicative. Short '
#                  'play sessions, mixed with naps and meals are their perfect '
#                  'day. Whilst appreciating any attention you give them, they '
#                  'are not demanding, content instead to follow you around '
#                  'devotedly, sleep on your bed and snuggle with you if you’re '
#                  'not feeling well.',
#   'ID': 'char',
#   'Image URL': 'https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Chartreux',
#   'Origin': 'France',
#   'Weight (kg)': 5.0,
#   'temperament': 'Affectionate, Loyal, Intelligent, Social, Lively, Playful'},
#  {'Description': 'For those owners who desire a feline capable of evoking the '
#                  'great outdoors, the strikingly beautiful Chausie retains a '
#                  'bit of the wild in its appearance but has the house manners '
#                  'of our friendly, familiar moggies. Very playful, this cat '
#                  'needs a large amount of space to be able to fully embrace '
#                  'its hunting instincts.',
#   'ID': 'chau',
#   'Image URL': 'https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Chausie',
#   'Origin': 'Egypt',
#   'Weight (kg)': 5.0,
#   'temperament': 'Affectionate, Intelligent, Playful, Social'},
#  {'Description': 'The Cheetoh has a super affectionate nature and real love '
#                  'for their human companions; they are intelligent with the '
#                  'ability to learn quickly. You can expect that a Cheetoh will '
#                  'be a fun-loving kitty who enjoys playing, running, and '
#                  'jumping through every room in your house.',
#   'ID': 'chee',
#   'Image URL': 'https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Cheetoh',
#   'Origin': 'United States',
#   'Weight (kg)': 5.5,
#   'temperament': 'Affectionate, Gentle, Intelligent, Social'},
#  {'Description': 'Colorpoint Shorthairs are an affectionate breed, devoted and '
#                  'loyal to their people. Sensitive to their owner’s moods, '
#                  'Colorpoints are more than happy to sit at your side or on '
#                  'your lap and purr words of encouragement on a bad day. They '
#                  'will constantly seek out your lap whenever it is open and in '
#                  'the moments when your lap is preoccupied they will stretch '
#                  'out in sunny spots on the ground.',
#   'ID': 'csho',
#   'Image URL': 'https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'Colorpoint Shorthair',
#   'Origin': 'United States',
#   'Weight (kg)': 3.5,
#   'temperament': 'Affectionate, Intelligent, Playful, Social'},
#  {'Description': 'This is a confident cat who loves people and will follow '
#                  'them around, waiting for any opportunity to sit in a lap or '
#                  'give a kiss. He enjoys being handled, making it easy to take '
#                  'him to the veterinarian or train him for therapy work. The '
#                  'Cornish Rex stay in kitten mode most of their lives and well '
#                  'into their senior years. ',
#   'ID': 'crex',
#   'Image URL': 'https://cdn2.thecatapi.com/images/unX21IBVB.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Cornish Rex',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 3.0,
#   'temperament': 'Affectionate, Intelligent, Active, Curious, Playful'},
#  {'Description': 'The Cymric is a placid, sweet cat. They do not get too upset '
#                  'about anything that happens in their world. They are loving '
#                  'companions and adore people. They are smart and dexterous, '
#                  'capable of using his paws to get into cabinets or to open '
#                  'doors.',
#   'ID': 'cymr',
#   'Image URL': 'https://cdn2.thecatapi.com/images/3dbtapCWM.jpg',
#   'Life Span (years)': 11.0,
#   'Name': 'Cymric',
#   'Origin': 'Canada',
#   'Weight (kg)': 5.0,
#   'temperament': 'Gentle, Loyal, Intelligent, Playful'},
#  {'Description': 'Loving, loyal, social and inquisitive, the Cyprus cat forms '
#                  'strong ties with their families and love nothing more than '
#                  'to be involved in everything that goes on in their '
#                  'surroundings. They are not overly active by nature which '
#                  'makes them the perfect companion for people who would like '
#                  'to share their homes with a laid-back relaxed feline '
#                  'companion. ',
#   'ID': 'cypr',
#   'Image URL': 'https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Cyprus',
#   'Origin': 'Cyprus',
#   'Weight (kg)': 5.5,
#   'temperament': 'Affectionate, Social'},
#  {'Description': 'The favourite perch of the Devon Rex is right at head level, '
#                  'on the shoulder of her favorite person. She takes a lively '
#                  'interest in everything that is going on and refuses to be '
#                  'left out of any activity. Count on her to stay as close to '
#                  'you as possible, occasionally communicating his opinions in '
#                  'a quiet voice. She loves people and welcomes the attentions '
#                  'of friends and family alike.',
#   'ID': 'drex',
#   'Image URL': 'https://cdn2.thecatapi.com/images/4RzEwvyzz.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Devon Rex',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 3.5,
#   'temperament': 'Highly interactive, Mischievous, Loyal, Social, Playful'},
#  {'Description': 'Donskoy are affectionate, intelligent, and easy-going. They '
#                  'demand lots of attention and interaction. The Donskoy also '
#                  'gets along well with other pets. It is now thought the same '
#                  'gene that causes degrees of hairlessness in the Donskoy also '
#                  'causes alterations in cat personality, making them calmer '
#                  'the less hair they have.',
#   'ID': 'dons',
#   'Image URL': 'https://cdn2.thecatapi.com/images/3KG57GfMW.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Donskoy',
#   'Origin': 'Russia',
#   'Weight (kg)': 5.5,
#   'temperament': 'Playful, affectionate, loyal, social'},
#  {'Description': 'The Dragon Li is loyal, but not particularly affectionate. '
#                  'They are known to be very intelligent, and their natural '
#                  "breed status means that they're very active. She is is "
#                  'gentle with people, and has a reputation as a talented '
#                  'hunter of rats and other vermin.',
#   'ID': 'lihu',
#   'Image URL': 'https://cdn2.thecatapi.com/images/BQMSld0A0.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Dragon Li',
#   'Origin': 'China',
#   'Weight (kg)': 5.0,
#   'temperament': 'Intelligent, Friendly, Gentle, Loving, Loyal'},
#  {'Description': 'The Egyptian Mau is gentle and reserved. She loves her '
#                  'people and desires attention and affection from them but is '
#                  'wary of others. Early, continuing socialization is essential '
#                  'with this sensitive and sometimes shy cat, especially if you '
#                  'plan to show or travel with her. Otherwise, she can be '
#                  'easily startled by unexpected noises or events.',
#   'ID': 'emau',
#   'Image URL': 'https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg',
#   'Life Span (years)': 19.0,
#   'Name': 'Egyptian Mau',
#   'Origin': 'Egypt',
#   'Weight (kg)': 4.5,
#   'temperament': 'Agile, Dependent, Gentle, Intelligent, Lively, Loyal, '
#                  'Playful'},
#  {'Description': 'The European Burmese is a very affectionate, intelligent, '
#                  'and loyal cat. They thrive on companionship and will want to '
#                  'be with you, participating in everything you do. While they '
#                  'might pick a favorite family member, chances are that they '
#                  'will interact with everyone in the home, as well as any '
#                  'visitors that come to call. They are inquisitive and '
#                  'playful, even as adults. ',
#   'ID': 'ebur',
#   'Image URL': '',
#   'Life Span (years)': 12.5,
#   'Name': 'European Burmese',
#   'Origin': 'Burma',
#   'Weight (kg)': 4.5,
#   'temperament': 'Sweet, Affectionate, Loyal'},
#  {'Description': 'The Exotic Shorthair is a gentle friendly cat that has the '
#                  'same personality as the Persian. They love having fun, don’t '
#                  'mind the company of other cats and dogs, also love to curl '
#                  'up for a sleep in a safe place. Exotics love their own '
#                  'people, but around strangers they are cautious at first. '
#                  'Given time, they usually warm up to visitors.',
#   'ID': 'esho',
#   'Image URL': 'https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Exotic Shorthair',
#   'Origin': 'United States',
#   'Weight (kg)': 4.5,
#   'temperament': 'Affectionate, Sweet, Loyal, Quiet, Peaceful'},
#  {'Description': 'The Havana Brown is human oriented, playful, and curious. '
#                  'She has a strong desire to spend time with her people and '
#                  'involve herself in everything they do. Being naturally '
#                  'inquisitive, the Havana Brown reaches out with a paw to '
#                  'touch and feel when investigating curiosities in its '
#                  'environment. They are truly sensitive by nature and '
#                  'frequently gently touch their human companions as if they '
#                  'are extending a paw of friendship.',
#   'ID': 'hbro',
#   'Image URL': 'https://cdn2.thecatapi.com/images/njK25knLH.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Havana Brown',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 4.0,
#   'temperament': 'Affectionate, Curious, Demanding, Friendly, Intelligent, '
#                  'Playful'},
#  {'Description': 'Calm and devoted, Himalayans make excellent companions, '
#                  'though they prefer a quieter home. They are playful in a '
#                  'sedate kind of way and enjoy having an assortment of toys. '
#                  'The Himalayan will stretch out next to you, sleep in your '
#                  'bed and even sit on your lap when she is in the mood.',
#   'ID': 'hima',
#   'Image URL': 'https://cdn2.thecatapi.com/images/CDhOtM-Ig.jpg',
#   'Life Span (years)': 12.0,
#   'Name': 'Himalayan',
#   'Origin': 'United States',
#   'Weight (kg)': 4.5,
#   'temperament': 'Dependent, Gentle, Intelligent, Quiet, Social'},
#  {'Description': 'The Japanese Bobtail is an active, sweet, loving and highly '
#                  'intelligent breed. They love to be with people and play '
#                  'seemingly endlessly. They learn their name and respond to '
#                  'it. They bring toys to people and play fetch with a favorite '
#                  'toy for hours. Bobtails are social and are at their best '
#                  'when in the company of people. They take over the house and '
#                  'are not intimidated. If a dog is in the house, Bobtails '
#                  'assume Bobtails are in charge.',
#   'ID': 'jbob',
#   'Image URL': 'https://cdn2.thecatapi.com/images/-tm9-znzl.jpg',
#   'Life Span (years)': 15.0,
#   'Name': 'Japanese Bobtail',
#   'Origin': 'Japan',
#   'Weight (kg)': 3.5,
#   'temperament': 'Active, Agile, Clever, Easy Going, Intelligent, Lively, '
#                  'Loyal, Playful, Social'},
#  {'Description': 'Javanese are endlessly interested, intelligent and active. '
#                  'They tend to enjoy jumping to great heights, playing with '
#                  'fishing pole-type or other interactive toys and just '
#                  'generally investigating their surroundings. He will attempt '
#                  'to copy things you do, such as opening doors or drawers.',
#   'ID': 'java',
#   'Image URL': 'https://cdn2.thecatapi.com/images/xoI_EpOKe.jpg',
#   'Life Span (years)': 11.0,
#   'Name': 'Javanese',
#   'Origin': 'United States',
#   'Weight (kg)': 3.5,
#   'temperament': 'Active, Devoted, Intelligent, Playful'},
#  {'Description': 'The Khao Manee is highly intelligent, with an extrovert and '
#                  'inquisitive nature, however they are also very calm and '
#                  'relaxed, making them an idea lap cat.',
#   'ID': 'khao',
#   'Image URL': 'https://cdn2.thecatapi.com/images/165ok6ESN.jpg',
#   'Life Span (years)': 11.0,
#   'Name': 'Khao Manee',
#   'Origin': 'Thailand',
#   'Weight (kg)': 5.0,
#   'temperament': 'Calm, Relaxed, Talkative, Playful, Warm'},
#  {'Description': 'The Korat is a natural breed, and one of the oldest stable '
#                  'cat breeds. They are highly intelligent and confident cats '
#                  'that can be fearless, although they are startled by loud '
#                  'sounds and sudden movements. Korats form strong bonds with '
#                  'their people and like to cuddle and stay nearby.',
#   'ID': 'kora',
#   'Image URL': 'https://cdn2.thecatapi.com/images/DbwiefiaY.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Korat',
#   'Origin': 'Thailand',
#   'Weight (kg)': 4.0,
#   'temperament': 'Active, Loyal, highly intelligent, Expressive, Trainable'},
#  {'Description': 'The character of the Kurilian Bobtail is independent, highly '
#                  'intelligent, clever, inquisitive, sociable, playful, '
#                  'trainable, absent of aggression and very gentle. They are '
#                  'devoted to their humans and when allowed are either on the '
#                  'lap of or sleeping in bed with their owners.',
#   'ID': 'kuri',
#   'Image URL': 'https://cdn2.thecatapi.com/images/NZpO4pU56M.jpg',
#   'Life Span (years)': 17.5,
#   'Name': 'Kurilian',
#   'Origin': 'Russia',
#   'Weight (kg)': 5.5,
#   'temperament': 'Independent, highly intelligent, clever, inquisitive, '
#                  'sociable, playful, trainable'},
#  {'Description': 'LaPerms are gentle and affectionate but also very active. '
#                  'Unlike many active breeds, the LaPerm is also quite content '
#                  'to be a lap cat. The LaPerm will often follow your lead; '
#                  'that is, if they are busy playing and you decide to sit and '
#                  'relax, simply pick up your LaPerm and sit down with it, and '
#                  'it will stay in your lap, devouring the attention you give '
#                  'it.',
#   'ID': 'lape',
#   'Image URL': 'https://cdn2.thecatapi.com/images/aKbsEYjSl.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'LaPerm',
#   'Origin': 'Thailand',
#   'Weight (kg)': 4.0,
#   'temperament': 'Affectionate, Friendly, Gentle, Intelligent, Playful, Quiet'},
#  {'Description': 'They are known for their size and luxurious long coat Maine '
#                  'Coons are considered a gentle giant. The good-natured and '
#                  'affable Maine Coon adapts well to many lifestyles and '
#                  'personalities. She likes being with people and has the habit '
#                  'of following them around, but isn’t needy. Most Maine Coons '
#                  'love water and they can be quite good swimmers.',
#   'ID': 'mcoo',
#   'Image URL': 'https://cdn2.thecatapi.com/images/OOD3VXAQn.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Maine Coon',
#   'Origin': 'United States',
#   'Weight (kg)': 6.5,
#   'temperament': 'Adaptable, Intelligent, Loving, Gentle, Independent'},
#  {'Description': 'Malayans love to explore and even enjoy traveling by way of '
#                  'a cat carrier. They are quite a talkative and rather loud '
#                  'cat with an apparent strong will. These cats will make sure '
#                  'that you give it the attention it seeks and always seem to '
#                  'want to be held and hugged. They will constantly interact '
#                  'with people, even strangers. They love to play and cuddle.',
#   'ID': 'mala',
#   'Image URL': '',
#   'Life Span (years)': 15.0,
#   'Name': 'Malayan',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 4.5,
#   'temperament': 'Affectionate, Interactive, Playful, Social'},
#  {'Description': 'The Manx is a placid, sweet cat that is gentle and playful. '
#                  'She never seems to get too upset about anything. She is a '
#                  'loving companion and adores being with people.',
#   'ID': 'manx',
#   'Image URL': 'https://cdn2.thecatapi.com/images/fhYh2PDcC.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Manx',
#   'Origin': 'Isle of Man',
#   'Weight (kg)': 4.5,
#   'temperament': 'Easy Going, Intelligent, Loyal, Playful, Social'},
#  {'Description': 'The Munchkin is an outgoing cat who enjoys being handled. '
#                  'She has lots of energy and is faster and more agile than she '
#                  'looks. The shortness of their legs does not seem to '
#                  'interfere with their running and leaping abilities.',
#   'ID': 'munc',
#   'Image URL': 'https://cdn2.thecatapi.com/images/j5cVSqLer.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Munchkin',
#   'Origin': 'United States',
#   'Weight (kg)': 3.0,
#   'temperament': 'Agile, Easy Going, Intelligent, Playful'},
#  {'Description': 'The Nebelung may have a reserved nature, but she loves to '
#                  'play (being especially fond of retrieving) and enjoys '
#                  'jumping or climbing to high places where she can study '
#                  'people and situations at her leisure before making up her '
#                  'mind about whether she wants to get involved.',
#   'ID': 'nebe',
#   'Image URL': 'https://cdn2.thecatapi.com/images/OGTWqNNOt.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Nebelung',
#   'Origin': 'United States',
#   'Weight (kg)': 4.0,
#   'temperament': 'Gentle, Quiet, Shy, Playful'},
#  {'Description': 'The Norwegian Forest Cat is a sweet, loving cat. She '
#                  'appreciates praise and loves to interact with her parent. '
#                  'She makes a loving companion and bonds with her parents once '
#                  'she accepts them for her own. She is still a hunter at '
#                  'heart. She loves to chase toys as if they are real. She is '
#                  'territorial and patrols several times each day to make '
#                  'certain that all is fine.',
#   'ID': 'norw',
#   'Image URL': 'https://cdn2.thecatapi.com/images/06dgGmEOV.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'Norwegian Forest Cat',
#   'Origin': 'Norway',
#   'Weight (kg)': 5.5,
#   'temperament': 'Sweet, Active, Intelligent, Social, Playful, Lively, '
#                  'Curious'},
#  {'Description': 'Loyal and devoted to their owners, the Ocicat is '
#                  'intelligent, confident, outgoing, and seems to have many dog '
#                  'traits. They can be trained to fetch toys, walk on a lead, '
#                  "taught to 'speak', come when called, and follow other "
#                  'commands. ',
#   'ID': 'ocic',
#   'Image URL': 'https://cdn2.thecatapi.com/images/JAx-08Y0n.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Ocicat',
#   'Origin': 'United States',
#   'Weight (kg)': 5.0,
#   'temperament': 'Active, Agile, Curious, Demanding, Friendly, Gentle, Lively, '
#                  'Playful, Social'},
#  {'Description': 'Orientals are passionate about the people in their lives. '
#                  'They become extremely attached to their humans, so be '
#                  'prepared for a lifetime commitment. When you are not '
#                  'available to entertain her, an Oriental will divert herself '
#                  'by jumping on top of the refrigerator, opening drawers, '
#                  'seeking out new hideaways.',
#   'ID': 'orie',
#   'Image URL': 'https://cdn2.thecatapi.com/images/LutjkZJpH.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Oriental',
#   'Origin': 'United States',
#   'Weight (kg)': 3.5,
#   'temperament': 'Energetic, Affectionate, Intelligent, Social, Playful, '
#                  'Curious'},
#  {'Description': 'Persians are sweet, gentle cats that can be playful or quiet '
#                  'and laid-back. Great with families and children, they '
#                  'absolutely love to lounge around the house. While they don’t '
#                  'mind a full house or active kids, they’ll usually hide when '
#                  'they need some alone time.',
#   'ID': 'pers',
#   'Image URL': 'https://cdn2.thecatapi.com/images/-Zfz5z2jK.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Persian',
#   'Origin': 'Iran (Persia)',
#   'Weight (kg)': 5.0,
#   'temperament': 'Affectionate, loyal, Sedate, Quiet'},
#  {'Description': 'Companionable and affectionate, the Pixie-bob wants to be an '
#                  'integral part of the family. The Pixie-Bob’s ability to bond '
#                  'with their humans along with their patient personas make '
#                  'them excellent companions for children.',
#   'ID': 'pixi',
#   'Image URL': 'https://cdn2.thecatapi.com/images/z7fJRNeN6.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Pixie-bob',
#   'Origin': 'United States',
#   'Weight (kg)': 6.0,
#   'temperament': 'Affectionate, Social, Intelligent, Loyal'},
#  {'Description': 'The Ragamuffin is calm, even tempered and gets along well '
#                  'with all family members. Changes in routine generally do not '
#                  'upset her. She is an ideal companion for those in '
#                  'apartments, and with children due to her patient nature.',
#   'ID': 'raga',
#   'Image URL': 'https://cdn2.thecatapi.com/images/SMuZx-bFM.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'Ragamuffin',
#   'Origin': 'United States',
#   'Weight (kg)': 6.5,
#   'temperament': 'Affectionate, Friendly, Gentle, Calm'},
#  {'Description': 'Ragdolls love their people, greeting them at the door, '
#                  'following them around the house, and leaping into a lap or '
#                  'snuggling in bed whenever given the chance. They are the '
#                  'epitome of a lap cat, enjoy being carried and collapsing '
#                  'into the arms of anyone who holds them.',
#   'ID': 'ragd',
#   'Image URL': 'https://cdn2.thecatapi.com/images/oGefY4YoG.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Ragdoll',
#   'Origin': 'United States',
#   'Weight (kg)': 7.0,
#   'temperament': 'Affectionate, Friendly, Gentle, Quiet, Easygoing'},
#  {'Description': 'Russian Blues are very loving and reserved. They do not like '
#                  'noisy households but they do like to play and can be quite '
#                  'active when outdoors. They bond very closely with their '
#                  'owner and are known to be compatible with other pets.',
#   'ID': 'rblu',
#   'Image URL': 'https://cdn2.thecatapi.com/images/Rhj-JsTLP.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Russian Blue',
#   'Origin': 'Russia',
#   'Weight (kg)': 3.5,
#   'temperament': 'Active, Dependent, Easy Going, Gentle, Intelligent, Loyal, '
#                  'Playful, Quiet'},
#  {'Description': 'Savannah is the feline version of a dog. Actively seeking '
#                  'social interaction, they are given to pouting if left out. '
#                  'Remaining kitten-like through life. Profoundly loyal to '
#                  'immediate family members whilst questioning the presence of '
#                  'strangers. Making excellent companions that are loyal, '
#                  'intelligent and eager to be involved.',
#   'ID': 'sava',
#   'Image URL': 'https://cdn2.thecatapi.com/images/a8nIYvs6S.jpg',
#   'Life Span (years)': 18.5,
#   'Name': 'Savannah',
#   'Origin': 'United States',
#   'Weight (kg)': 7.5,
#   'temperament': 'Curious, Social, Intelligent, Loyal, Outgoing, Adventurous, '
#                  'Affectionate'},
#  {'Description': 'The Scottish Fold is a sweet, charming breed. She is an easy '
#                  'cat to live with and to care for. She is affectionate and is '
#                  'comfortable with all members of her family. Her tail should '
#                  'be handled gently. Folds are known for sleeping on their '
#                  'backs, and for sitting with their legs stretched out and '
#                  'their paws on their belly. This is called the "Buddha '
#                  'Position".',
#   'ID': 'sfol',
#   'Image URL': 'https://cdn2.thecatapi.com/images/o9t0LDcsa.jpg',
#   'Life Span (years)': 12.5,
#   'Name': 'Scottish Fold',
#   'Origin': 'United Kingdom',
#   'Weight (kg)': 3.5,
#   'temperament': 'Affectionate, Intelligent, Loyal, Playful, Social, Sweet, '
#                  'Loving'},
#  {'Description': 'The Selkirk Rex is an incredibly patient, loving, and '
#                  'tolerant breed. The Selkirk also has a silly side and is '
#                  'sometimes described as clownish. She loves being a lap cat '
#                  'and will be happy to chat with you in a quiet voice if you '
#                  'talk to her. ',
#   'ID': 'srex',
#   'Image URL': 'https://cdn2.thecatapi.com/images/II9dOZmrw.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Selkirk Rex',
#   'Origin': 'United States',
#   'Weight (kg)': 5.0,
#   'temperament': 'Active, Affectionate, Dependent, Gentle, Patient, Playful, '
#                  'Quiet, Social'},
#  {'Description': 'While Siamese cats are extremely fond of their people, they '
#                  'will follow you around and supervise your every move, being '
#                  'talkative and opinionated. They are a demanding and social '
#                  'cat, that do not like being left alone for long periods.',
#   'ID': 'siam',
#   'Image URL': 'https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Siamese',
#   'Origin': 'Thailand',
#   'Weight (kg)': 5.5,
#   'temperament': 'Active, Agile, Clever, Sociable, Loving, Energetic'},
#  {'Description': 'The Siberians dog like temperament and affection makes the '
#                  'ideal lap cat and will live quite happily indoors. Very '
#                  'agile and powerful, the Siberian cat can easily leap and '
#                  'reach high places, including the tops of refrigerators and '
#                  'even doors. ',
#   'ID': 'sibe',
#   'Image URL': 'https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Siberian',
#   'Origin': 'Russia',
#   'Weight (kg)': 5.5,
#   'temperament': 'Curious, Intelligent, Loyal, Sweet, Agile, Playful, '
#                  'Affectionate'},
#  {'Description': 'The Singapura is usually cautious when it comes to meeting '
#                  'new people, but loves attention from his family so much that '
#                  'she sometimes has the reputation of being a pest. This is a '
#                  'highly active, curious and affectionate cat. She may be '
#                  'small, but she knows she’s in charge',
#   'ID': 'sing',
#   'Image URL': 'https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Singapura',
#   'Origin': 'Singapore',
#   'Weight (kg)': 3.0,
#   'temperament': 'Affectionate, Curious, Easy Going, Intelligent, Interactive, '
#                  'Lively, Loyal'},
#  {'Description': 'The Snowshoe is a vibrant, energetic, affectionate and '
#                  'intelligent cat. They love being around people which makes '
#                  'them ideal for families, and becomes unhappy when left alone '
#                  'for long periods of time. Usually attaching themselves to '
#                  'one person, they do whatever they can to get your attention.',
#   'ID': 'snow',
#   'Image URL': 'https://cdn2.thecatapi.com/images/MK-sYESvO.jpg',
#   'Life Span (years)': 16.5,
#   'Name': 'Snowshoe',
#   'Origin': 'United States',
#   'Weight (kg)': 4.0,
#   'temperament': 'Affectionate, Social, Intelligent, Sweet-tempered'},
#  {'Description': 'The Somali lives life to the fullest. He climbs higher, '
#                  'jumps farther, plays harder. Nothing escapes the notice of '
#                  'this highly intelligent and inquisitive cat. Somalis love '
#                  'the company of humans and other animals.',
#   'ID': 'soma',
#   'Image URL': 'https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'Somali',
#   'Origin': 'Somalia',
#   'Weight (kg)': 4.0,
#   'temperament': 'Mischievous, Tenacious, Intelligent, Affectionate, Gentle, '
#                  'Interactive, Loyal'},
#  {'Description': 'The Sphynx is an intelligent, inquisitive, extremely '
#                  'friendly people-oriented breed. Sphynx commonly greet their '
#                  'owners  at the front door, with obvious excitement and '
#                  'happiness. She has an unexpected sense of humor that is '
#                  'often at odds with her dour expression.',
#   'ID': 'sphy',
#   'Image URL': 'https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg',
#   'Life Span (years)': 13.0,
#   'Name': 'Sphynx',
#   'Origin': 'Canada',
#   'Weight (kg)': 4.0,
#   'temperament': 'Loyal, Inquisitive, Friendly, Quiet, Gentle'},
#  {'Description': 'Intelligent and generous with their affection, a Tonkinese '
#                  'will supervise all activities with curiosity. Loving, '
#                  'social, active, playful, yet content to be a lap cat',
#   'ID': 'tonk',
#   'Image URL': 'https://cdn2.thecatapi.com/images/KBroiVNCM.jpg',
#   'Life Span (years)': 15.0,
#   'Name': 'Tonkinese',
#   'Origin': 'Canada',
#   'Weight (kg)': 4.0,
#   'temperament': 'Curious, Intelligent, Social, Lively, Outgoing, Playful, '
#                  'Affectionate'},
#  {'Description': 'The Toyger has a sweet, calm personality and is generally '
#                  "friendly. He's outgoing enough to walk on a leash, energetic "
#                  'enough to play fetch and other interactive games, and '
#                  'confident enough to get along with other cats and friendly '
#                  'dogs.',
#   'ID': 'toyg',
#   'Image URL': 'https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg',
#   'Life Span (years)': 13.5,
#   'Name': 'Toyger',
#   'Origin': 'United States',
#   'Weight (kg)': 5.0,
#   'temperament': 'Playful, Social, Intelligent'},
#  {'Description': 'This is a smart and intelligent cat which bonds well with '
#                  'humans. With its affectionate and playful personality the '
#                  'Angora is a top choice for families. The Angora gets along '
#                  'great with other pets in the home, but it will make clear '
#                  'who is in charge, and who the house belongs to',
#   'ID': 'tang',
#   'Image URL': 'https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg',
#   'Life Span (years)': 16.5,
#   'Name': 'Turkish Angora',
#   'Origin': 'Turkey',
#   'Weight (kg)': 3.5,
#   'temperament': 'Affectionate, Agile, Clever, Gentle, Intelligent, Playful, '
#                  'Social'},
#  {'Description': 'While the Turkish Van loves to jump and climb, play with '
#                  'toys, retrieve and play chase, she is is big and ungainly; '
#                  'this is one cat who doesn’t always land on his feet. While '
#                  'not much of a lap cat, the Van will be happy to cuddle next '
#                  'to you and sleep in your bed. ',
#   'ID': 'tvan',
#   'Image URL': 'https://cdn2.thecatapi.com/images/sxIXJax6h.jpg',
#   'Life Span (years)': 14.5,
#   'Name': 'Turkish Van',
#   'Origin': 'Turkey',
#   'Weight (kg)': 6.0,
#   'temperament': 'Agile, Intelligent, Loyal, Playful, Energetic'},
#  {'Description': 'York Chocolate cats are known to be true lap cats with a '
#                  'sweet temperament. They love to be cuddled and petted. Their '
#                  'curious nature makes them follow you all the time and '
#                  "participate in almost everything you do, even if it's "
#                  'related to water: unlike many other cats, York Chocolates '
#                  'love it.',
#   'ID': 'ycho',
#   'Image URL': 'https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg',
#   'Life Span (years)': 14.0,
#   'Name': 'York Chocolate',
#   'Origin': 'United States',
#   'Weight (kg)': 6.5,
#   'temperament': 'Playful, Social, Intelligent, Curious, Friendly'}]

# %%
cats_data_frame = pd.DataFrame(cats)

# %%
cats_data_frame.to_csv('cats.csv', index=False)

# %%
df = pd.read_csv('./cats.csv')

# %%
df.head()
# Out:
#      ID                Name         Origin  \
# 0  abys          Abyssinian          Egypt
# 1  aege              Aegean         Greece
# 2  abob    American Bobtail  United States
# 3  acur       American Curl  United States
# 4  asho  American Shorthair  United States
#
#                                          Description  Weight (kg)  \
# 0  The Abyssinian is easy to care for, and a joy ...          4.0
# 1  Native to the Greek islands known as the Cycla...          4.0
# 2  American Bobtails are loving and incredibly in...          5.0
# 3  Distinguished by truly unique ears that curl b...          3.5
# 4  The American Shorthair is known for its longev...          5.5
#
#    Life Span (years)                                        temperament  \
# 0               14.5  Active, Energetic, Independent, Intelligent, G...
# 1               10.5  Affectionate, Social, Intelligent, Playful, Ac...
# 2               13.0  Intelligent, Interactive, Lively, Playful, Sen...
# 3               14.0  Affectionate, Curious, Intelligent, Interactiv...
# 4               16.0         Active, Curious, Easy Going, Playful, Calm
#
#                                          Image URL
# 0  https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
# 1  https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg
# 2  https://cdn2.thecatapi.com/images/hBXicehMA.jpg
# 3  https://cdn2.thecatapi.com/images/xnsqonbjW.jpg
# 4  https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg

# %%
df.tail()
# Out:
#       ID            Name         Origin  \
# 62  tonk       Tonkinese         Canada
# 63  toyg          Toyger  United States
# 64  tang  Turkish Angora         Turkey
# 65  tvan     Turkish Van         Turkey
# 66  ycho  York Chocolate  United States
#
#                                           Description  Weight (kg)  \
# 62  Intelligent and generous with their affection,...          4.0
# 63  The Toyger has a sweet, calm personality and i...          5.0
# 64  This is a smart and intelligent cat which bond...          3.5
# 65  While the Turkish Van loves to jump and climb,...          6.0
# 66  York Chocolate cats are known to be true lap c...          6.5
#
#     Life Span (years)                                        temperament  \
# 62               15.0  Curious, Intelligent, Social, Lively, Outgoing...
# 63               13.5                       Playful, Social, Intelligent
# 64               16.5  Affectionate, Agile, Clever, Gentle, Intellige...
# 65               14.5      Agile, Intelligent, Loyal, Playful, Energetic
# 66               14.0    Playful, Social, Intelligent, Curious, Friendly
#
#                                           Image URL
# 62  https://cdn2.thecatapi.com/images/KBroiVNCM.jpg
# 63  https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg
# 64  https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg
# 65  https://cdn2.thecatapi.com/images/sxIXJax6h.jpg
# 66  https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg

# %%
df
# Out:
#       ID                  Name                Origin  \
# 0   abys            Abyssinian                 Egypt
# 1   aege                Aegean                Greece
# 2   abob      American Bobtail         United States
# 3   acur         American Curl         United States
# 4   asho    American Shorthair         United States
# 5   awir     American Wirehair         United States
# 6   amau           Arabian Mau  United Arab Emirates
# 7   amis       Australian Mist             Australia
# 8   bali              Balinese         United States
# 9   bamb               Bambino         United States
# 10  beng                Bengal         United States
# 11  birm                Birman                France
# 12  bomb                Bombay         United States
# 13  bslo      British Longhair        United Kingdom
# 14  bsho     British Shorthair        United Kingdom
# 15  bure               Burmese                 Burma
# 16  buri              Burmilla        United Kingdom
# 17  cspa   California Spangled         United States
# 18  ctif     Chantilly-Tiffany         United States
# 19  char             Chartreux                France
# 20  chau               Chausie                 Egypt
# 21  chee               Cheetoh         United States
# 22  csho  Colorpoint Shorthair         United States
# 23  crex           Cornish Rex        United Kingdom
# 24  cymr                Cymric                Canada
# 25  cypr                Cyprus                Cyprus
# 26  drex             Devon Rex        United Kingdom
# 27  dons               Donskoy                Russia
# 28  lihu             Dragon Li                 China
# 29  emau          Egyptian Mau                 Egypt
# 30  ebur      European Burmese                 Burma
# 31  esho      Exotic Shorthair         United States
# 32  hbro          Havana Brown        United Kingdom
# 33  hima             Himalayan         United States
# 34  jbob      Japanese Bobtail                 Japan
# 35  java              Javanese         United States
# 36  khao            Khao Manee              Thailand
# 37  kora                 Korat              Thailand
# 38  kuri              Kurilian                Russia
# 39  lape                LaPerm              Thailand
# 40  mcoo            Maine Coon         United States
# 41  mala               Malayan        United Kingdom
# 42  manx                  Manx           Isle of Man
# 43  munc              Munchkin         United States
# 44  nebe              Nebelung         United States
# 45  norw  Norwegian Forest Cat                Norway
# 46  ocic                Ocicat         United States
# 47  orie              Oriental         United States
# 48  pers               Persian         Iran (Persia)
# 49  pixi             Pixie-bob         United States
# 50  raga            Ragamuffin         United States
# 51  ragd               Ragdoll         United States
# 52  rblu          Russian Blue                Russia
# 53  sava              Savannah         United States
# 54  sfol         Scottish Fold        United Kingdom
# 55  srex           Selkirk Rex         United States
# 56  siam               Siamese              Thailand
# 57  sibe              Siberian                Russia
# 58  sing             Singapura             Singapore
# 59  snow              Snowshoe         United States
# 60  soma                Somali               Somalia
# 61  sphy                Sphynx                Canada
# 62  tonk             Tonkinese                Canada
# 63  toyg                Toyger         United States
# 64  tang        Turkish Angora                Turkey
# 65  tvan           Turkish Van                Turkey
# 66  ycho        York Chocolate         United States
#
#                                           Description  Weight (kg)  \
# 0   The Abyssinian is easy to care for, and a joy ...          4.0
# 1   Native to the Greek islands known as the Cycla...          4.0
# 2   American Bobtails are loving and incredibly in...          5.0
# 3   Distinguished by truly unique ears that curl b...          3.5
# 4   The American Shorthair is known for its longev...          5.5
# 5   The American Wirehair tends to be a calm and t...          5.5
# 6   Arabian Mau cats are social and energetic. Due...          5.5
# 7   The Australian Mist thrives on human companion...          5.0
# 8   Balinese are curious, outgoing, intelligent ca...          3.5
# 9   The Bambino is a breed of cat that was created...          3.0
# 10  Bengals are a lot of fun to live with, but the...          5.0
# 11  The Birman is a docile, quiet cat who loves pe...          5.0
# 12  The the golden eyes and the shiny black coa of...          4.0
# 13  The British Longhair is a very laid-back relax...          6.0
# 14  The British Shorthair is a very pleasant cat t...          7.0
# 15  Burmese love being with people, playing with t...          4.0
# 16  The Burmilla is a fairly placid cat. She tends...          4.5
# 17  Perhaps the only thing about the California sp...          6.0
# 18  The Chantilly is a devoted companion and prefe...          4.0
# 19  The Chartreux is generally silent but communic...          5.0
# 20  For those owners who desire a feline capable o...          5.0
# 21  The Cheetoh has a super affectionate nature an...          5.5
# 22  Colorpoint Shorthairs are an affectionate bree...          3.5
# 23  This is a confident cat who loves people and w...          3.0
# 24  The Cymric is a placid, sweet cat. They do not...          5.0
# 25  Loving, loyal, social and inquisitive, the Cyp...          5.5
# 26  The favourite perch of the Devon Rex is right ...          3.5
# 27  Donskoy are affectionate, intelligent, and eas...          5.5
# 28  The Dragon Li is loyal, but not particularly a...          5.0
# 29  The Egyptian Mau is gentle and reserved. She l...          4.5
# 30  The European Burmese is a very affectionate, i...          4.5
# 31  The Exotic Shorthair is a gentle friendly cat ...          4.5
# 32  The Havana Brown is human oriented, playful, a...          4.0
# 33  Calm and devoted, Himalayans make excellent co...          4.5
# 34  The Japanese Bobtail is an active, sweet, lovi...          3.5
# 35  Javanese are endlessly interested, intelligent...          3.5
# 36  The Khao Manee is highly intelligent, with an ...          5.0
# 37  The Korat is a natural breed, and one of the o...          4.0
# 38  The character of the Kurilian Bobtail is indep...          5.5
# 39  LaPerms are gentle and affectionate but also v...          4.0
# 40  They are known for their size and luxurious lo...          6.5
# 41  Malayans love to explore and even enjoy travel...          4.5
# 42  The Manx is a placid, sweet cat that is gentle...          4.5
# 43  The Munchkin is an outgoing cat who enjoys bei...          3.0
# 44  The Nebelung may have a reserved nature, but s...          4.0
# 45  The Norwegian Forest Cat is a sweet, loving ca...          5.5
# 46  Loyal and devoted to their owners, the Ocicat ...          5.0
# 47  Orientals are passionate about the people in t...          3.5
# 48  Persians are sweet, gentle cats that can be pl...          5.0
# 49  Companionable and affectionate, the Pixie-bob ...          6.0
# 50  The Ragamuffin is calm, even tempered and gets...          6.5
# 51  Ragdolls love their people, greeting them at t...          7.0
# 52  Russian Blues are very loving and reserved. Th...          3.5
# 53  Savannah is the feline version of a dog. Activ...          7.5
# 54  The Scottish Fold is a sweet, charming breed. ...          3.5
# 55  The Selkirk Rex is an incredibly patient, lovi...          5.0
# 56  While Siamese cats are extremely fond of their...          5.5
# 57  The Siberians dog like temperament and affecti...          5.5
# 58  The Singapura is usually cautious when it come...          3.0
# 59  The Snowshoe is a vibrant, energetic, affectio...          4.0
# 60  The Somali lives life to the fullest. He climb...          4.0
# 61  The Sphynx is an intelligent, inquisitive, ext...          4.0
# 62  Intelligent and generous with their affection,...          4.0
# 63  The Toyger has a sweet, calm personality and i...          5.0
# 64  This is a smart and intelligent cat which bond...          3.5
# 65  While the Turkish Van loves to jump and climb,...          6.0
# 66  York Chocolate cats are known to be true lap c...          6.5
#
#     Life Span (years)                                        temperament  \
# 0                14.5  Active, Energetic, Independent, Intelligent, G...
# 1                10.5  Affectionate, Social, Intelligent, Playful, Ac...
# 2                13.0  Intelligent, Interactive, Lively, Playful, Sen...
# 3                14.0  Affectionate, Curious, Intelligent, Interactiv...
# 4                16.0         Active, Curious, Easy Going, Playful, Calm
# 5                16.0  Affectionate, Curious, Gentle, Intelligent, In...
# 6                13.0  Affectionate, Agile, Curious, Independent, Pla...
# 7                14.0  Lively, Social, Fun-loving, Relaxed, Affectionate
# 8                12.5                 Affectionate, Intelligent, Playful
# 9                13.0        Affectionate, Lively, Friendly, Intelligent
# 10               13.5    Alert, Agile, Energetic, Demanding, Intelligent
# 11               14.5               Affectionate, Active, Gentle, Social
# 12               14.0  Affectionate, Dependent, Gentle, Intelligent, ...
# 13               13.0  Affectionate, Easy Going, Independent, Intelli...
# 14               14.5  Affectionate, Easy Going, Gentle, Loyal, Patie...
# 15               15.5  Curious, Intelligent, Gentle, Social, Interact...
# 16               12.5  Easy Going, Friendly, Intelligent, Lively, Pla...
# 17               12.0  Affectionate, Curious, Intelligent, Loyal, Social
# 18               15.0        Affectionate, Demanding, Interactive, Loyal
# 19               13.5  Affectionate, Loyal, Intelligent, Social, Live...
# 20               13.0         Affectionate, Intelligent, Playful, Social
# 21               13.0          Affectionate, Gentle, Intelligent, Social
# 22               14.0         Affectionate, Intelligent, Playful, Social
# 23               12.5  Affectionate, Intelligent, Active, Curious, Pl...
# 24               11.0                Gentle, Loyal, Intelligent, Playful
# 25               13.5                               Affectionate, Social
# 26               12.5  Highly interactive, Mischievous, Loyal, Social...
# 27               13.5               Playful, affectionate, loyal, social
# 28               13.5       Intelligent, Friendly, Gentle, Loving, Loyal
# 29               19.0  Agile, Dependent, Gentle, Intelligent, Lively,...
# 30               12.5                         Sweet, Affectionate, Loyal
# 31               13.5        Affectionate, Sweet, Loyal, Quiet, Peaceful
# 32               12.5  Affectionate, Curious, Demanding, Friendly, In...
# 33               12.0      Dependent, Gentle, Intelligent, Quiet, Social
# 34               15.0  Active, Agile, Clever, Easy Going, Intelligent...
# 35               11.0              Active, Devoted, Intelligent, Playful
# 36               11.0            Calm, Relaxed, Talkative, Playful, Warm
# 37               12.5  Active, Loyal, highly intelligent, Expressive,...
# 38               17.5  Independent, highly intelligent, clever, inqui...
# 39               12.5  Affectionate, Friendly, Gentle, Intelligent, P...
# 40               13.5  Adaptable, Intelligent, Loving, Gentle, Indepe...
# 41               15.0         Affectionate, Interactive, Playful, Social
# 42               13.0    Easy Going, Intelligent, Loyal, Playful, Social
# 43               12.5            Agile, Easy Going, Intelligent, Playful
# 44               13.5                        Gentle, Quiet, Shy, Playful
# 45               14.0  Sweet, Active, Intelligent, Social, Playful, L...
# 46               13.0  Active, Agile, Curious, Demanding, Friendly, G...
# 47               13.0  Energetic, Affectionate, Intelligent, Social, ...
# 48               14.5                 Affectionate, loyal, Sedate, Quiet
# 49               14.5           Affectionate, Social, Intelligent, Loyal
# 50               14.0               Affectionate, Friendly, Gentle, Calm
# 51               14.5   Affectionate, Friendly, Gentle, Quiet, Easygoing
# 52               13.0  Active, Dependent, Easy Going, Gentle, Intelli...
# 53               18.5  Curious, Social, Intelligent, Loyal, Outgoing,...
# 54               12.5  Affectionate, Intelligent, Loyal, Playful, Soc...
# 55               14.5  Active, Affectionate, Dependent, Gentle, Patie...
# 56               13.5  Active, Agile, Clever, Sociable, Loving, Energ...
# 57               13.5  Curious, Intelligent, Loyal, Sweet, Agile, Pla...
# 58               13.5  Affectionate, Curious, Easy Going, Intelligent...
# 59               16.5  Affectionate, Social, Intelligent, Sweet-tempered
# 60               14.0  Mischievous, Tenacious, Intelligent, Affection...
# 61               13.0        Loyal, Inquisitive, Friendly, Quiet, Gentle
# 62               15.0  Curious, Intelligent, Social, Lively, Outgoing...
# 63               13.5                       Playful, Social, Intelligent
# 64               16.5  Affectionate, Agile, Clever, Gentle, Intellige...
# 65               14.5      Agile, Intelligent, Loyal, Playful, Energetic
# 66               14.0    Playful, Social, Intelligent, Curious, Friendly
#
#                                            Image URL
# 0    https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
# 1    https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg
# 2    https://cdn2.thecatapi.com/images/hBXicehMA.jpg
# 3    https://cdn2.thecatapi.com/images/xnsqonbjW.jpg
# 4    https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg
# 5    https://cdn2.thecatapi.com/images/8D--jCd21.jpg
# 6    https://cdn2.thecatapi.com/images/k71ULYfRr.jpg
# 7    https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg
# 8    https://cdn2.thecatapi.com/images/13MkvUreZ.jpg
# 9    https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg
# 10   https://cdn2.thecatapi.com/images/O3btzLlsO.jpg
# 11   https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg
# 12   https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg
# 13   https://cdn2.thecatapi.com/images/7isAO4Cav.jpg
# 14   https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg
# 15   https://cdn2.thecatapi.com/images/4lXnnfxac.jpg
# 16   https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg
# 17   https://cdn2.thecatapi.com/images/B1ERTmgph.jpg
# 18   https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg
# 19   https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg
# 20   https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg
# 21   https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg
# 22   https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg
# 23   https://cdn2.thecatapi.com/images/unX21IBVB.jpg
# 24   https://cdn2.thecatapi.com/images/3dbtapCWM.jpg
# 25   https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg
# 26   https://cdn2.thecatapi.com/images/4RzEwvyzz.jpg
# 27   https://cdn2.thecatapi.com/images/3KG57GfMW.jpg
# 28   https://cdn2.thecatapi.com/images/BQMSld0A0.jpg
# 29   https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg
# 30                                               NaN
# 31   https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg
# 32   https://cdn2.thecatapi.com/images/njK25knLH.jpg
# 33   https://cdn2.thecatapi.com/images/CDhOtM-Ig.jpg
# 34   https://cdn2.thecatapi.com/images/-tm9-znzl.jpg
# 35   https://cdn2.thecatapi.com/images/xoI_EpOKe.jpg
# 36   https://cdn2.thecatapi.com/images/165ok6ESN.jpg
# 37   https://cdn2.thecatapi.com/images/DbwiefiaY.jpg
# 38  https://cdn2.thecatapi.com/images/NZpO4pU56M.jpg
# 39   https://cdn2.thecatapi.com/images/aKbsEYjSl.jpg
# 40   https://cdn2.thecatapi.com/images/OOD3VXAQn.jpg
# 41                                               NaN
# 42   https://cdn2.thecatapi.com/images/fhYh2PDcC.jpg
# 43   https://cdn2.thecatapi.com/images/j5cVSqLer.jpg
# 44   https://cdn2.thecatapi.com/images/OGTWqNNOt.jpg
# 45   https://cdn2.thecatapi.com/images/06dgGmEOV.jpg
# 46   https://cdn2.thecatapi.com/images/JAx-08Y0n.jpg
# 47   https://cdn2.thecatapi.com/images/LutjkZJpH.jpg
# 48   https://cdn2.thecatapi.com/images/-Zfz5z2jK.jpg
# 49   https://cdn2.thecatapi.com/images/z7fJRNeN6.jpg
# 50   https://cdn2.thecatapi.com/images/SMuZx-bFM.jpg
# 51   https://cdn2.thecatapi.com/images/oGefY4YoG.jpg
# 52   https://cdn2.thecatapi.com/images/Rhj-JsTLP.jpg
# 53   https://cdn2.thecatapi.com/images/a8nIYvs6S.jpg
# 54   https://cdn2.thecatapi.com/images/o9t0LDcsa.jpg
# 55   https://cdn2.thecatapi.com/images/II9dOZmrw.jpg
# 56   https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg
# 57   https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg
# 58   https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg
# 59   https://cdn2.thecatapi.com/images/MK-sYESvO.jpg
# 60   https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg
# 61   https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg
# 62   https://cdn2.thecatapi.com/images/KBroiVNCM.jpg
# 63   https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg
# 64   https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg
# 65   https://cdn2.thecatapi.com/images/sxIXJax6h.jpg
# 66   https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Origin', 'Description', 'Weight (kg)',
#        'Life Span (years)', 'temperament', 'Image URL'],
#       dtype='object')

# %%
columns = list(df.columns)
columns
# Out:
# ['ID',
#  'Name',
#  'Origin',
#  'Description',
#  'Weight (kg)',
#  'Life Span (years)',
#  'temperament',
#  'Image URL']

# %%
df.shape
# Out:
# (67, 8)

# %%
df['Name']
# Out:
# 0               Abyssinian
# 1                   Aegean
# 2         American Bobtail
# 3            American Curl
# 4       American Shorthair
# 5        American Wirehair
# 6              Arabian Mau
# 7          Australian Mist
# 8                 Balinese
# 9                  Bambino
# 10                  Bengal
# 11                  Birman
# 12                  Bombay
# 13        British Longhair
# 14       British Shorthair
# 15                 Burmese
# 16                Burmilla
# 17     California Spangled
# 18       Chantilly-Tiffany
# 19               Chartreux
# 20                 Chausie
# 21                 Cheetoh
# 22    Colorpoint Shorthair
# 23             Cornish Rex
# 24                  Cymric
# 25                  Cyprus
# 26               Devon Rex
# 27                 Donskoy
# 28               Dragon Li
# 29            Egyptian Mau
# 30        European Burmese
# 31        Exotic Shorthair
# 32            Havana Brown
# 33               Himalayan
# 34        Japanese Bobtail
# 35                Javanese
# 36              Khao Manee
# 37                   Korat
# 38                Kurilian
# 39                  LaPerm
# 40              Maine Coon
# 41                 Malayan
# 42                    Manx
# 43                Munchkin
# 44                Nebelung
# 45    Norwegian Forest Cat
# 46                  Ocicat
# 47                Oriental
# 48                 Persian
# 49               Pixie-bob
# 50              Ragamuffin
# 51                 Ragdoll
# 52            Russian Blue
# 53                Savannah
# 54           Scottish Fold
# 55             Selkirk Rex
# 56                 Siamese
# 57                Siberian
# 58               Singapura
# 59                Snowshoe
# 60                  Somali
# 61                  Sphynx
# 62               Tonkinese
# 63                  Toyger
# 64          Turkish Angora
# 65             Turkish Van
# 66          York Chocolate
# Name: Name, dtype: object

# %%
df[['Name', 'Origin', 'Weight (kg)', 'Life Span (years)']]
# Out:
#                     Name                Origin  Weight (kg)  Life Span (years)
# 0             Abyssinian                 Egypt          4.0               14.5
# 1                 Aegean                Greece          4.0               10.5
# 2       American Bobtail         United States          5.0               13.0
# 3          American Curl         United States          3.5               14.0
# 4     American Shorthair         United States          5.5               16.0
# 5      American Wirehair         United States          5.5               16.0
# 6            Arabian Mau  United Arab Emirates          5.5               13.0
# 7        Australian Mist             Australia          5.0               14.0
# 8               Balinese         United States          3.5               12.5
# 9                Bambino         United States          3.0               13.0
# 10                Bengal         United States          5.0               13.5
# 11                Birman                France          5.0               14.5
# 12                Bombay         United States          4.0               14.0
# 13      British Longhair        United Kingdom          6.0               13.0
# 14     British Shorthair        United Kingdom          7.0               14.5
# 15               Burmese                 Burma          4.0               15.5
# 16              Burmilla        United Kingdom          4.5               12.5
# 17   California Spangled         United States          6.0               12.0
# 18     Chantilly-Tiffany         United States          4.0               15.0
# 19             Chartreux                France          5.0               13.5
# 20               Chausie                 Egypt          5.0               13.0
# 21               Cheetoh         United States          5.5               13.0
# 22  Colorpoint Shorthair         United States          3.5               14.0
# 23           Cornish Rex        United Kingdom          3.0               12.5
# 24                Cymric                Canada          5.0               11.0
# 25                Cyprus                Cyprus          5.5               13.5
# 26             Devon Rex        United Kingdom          3.5               12.5
# 27               Donskoy                Russia          5.5               13.5
# 28             Dragon Li                 China          5.0               13.5
# 29          Egyptian Mau                 Egypt          4.5               19.0
# 30      European Burmese                 Burma          4.5               12.5
# 31      Exotic Shorthair         United States          4.5               13.5
# 32          Havana Brown        United Kingdom          4.0               12.5
# 33             Himalayan         United States          4.5               12.0
# 34      Japanese Bobtail                 Japan          3.5               15.0
# 35              Javanese         United States          3.5               11.0
# 36            Khao Manee              Thailand          5.0               11.0
# 37                 Korat              Thailand          4.0               12.5
# 38              Kurilian                Russia          5.5               17.5
# 39                LaPerm              Thailand          4.0               12.5
# 40            Maine Coon         United States          6.5               13.5
# 41               Malayan        United Kingdom          4.5               15.0
# 42                  Manx           Isle of Man          4.5               13.0
# 43              Munchkin         United States          3.0               12.5
# 44              Nebelung         United States          4.0               13.5
# 45  Norwegian Forest Cat                Norway          5.5               14.0
# 46                Ocicat         United States          5.0               13.0
# 47              Oriental         United States          3.5               13.0
# 48               Persian         Iran (Persia)          5.0               14.5
# 49             Pixie-bob         United States          6.0               14.5
# 50            Ragamuffin         United States          6.5               14.0
# 51               Ragdoll         United States          7.0               14.5
# 52          Russian Blue                Russia          3.5               13.0
# 53              Savannah         United States          7.5               18.5
# 54         Scottish Fold        United Kingdom          3.5               12.5
# 55           Selkirk Rex         United States          5.0               14.5
# 56               Siamese              Thailand          5.5               13.5
# 57              Siberian                Russia          5.5               13.5
# 58             Singapura             Singapore          3.0               13.5
# 59              Snowshoe         United States          4.0               16.5
# 60                Somali               Somalia          4.0               14.0
# 61                Sphynx                Canada          4.0               13.0
# 62             Tonkinese                Canada          4.0               15.0
# 63                Toyger         United States          5.0               13.5
# 64        Turkish Angora                Turkey          3.5               16.5
# 65           Turkish Van                Turkey          6.0               14.5
# 66        York Chocolate         United States          6.5               14.0

# %%
df[['Name', 'Origin', 'Weight (kg)', 'Life Span (years)']].to_csv('simplified_cats_breed.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 67 non-null     object
#  1   Name               67 non-null     object
#  2   Origin             67 non-null     object
#  3   Description        67 non-null     object
#  4   Weight (kg)        67 non-null     float64
#  5   Life Span (years)  67 non-null     float64
#  6   temperament        67 non-null     object
#  7   Image URL          65 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 4.3+ KB

# %%
df.describe()
# Out:
#        Weight (kg)  Life Span (years)
# count    67.000000          67.000000
# mean      4.708955          13.746269
# std       1.066534           1.584425
# min       3.000000          10.500000
# 25%       4.000000          13.000000
# 50%       4.500000          13.500000
# 75%       5.500000          14.500000
# max       7.500000          19.000000

# %%
df.describe(include='all')
# Out:
#           ID        Name         Origin  \
# count     67          67             67
# unique    67          67             20
# top     abys  Abyssinian  United States
# freq       1           1             28
# mean     NaN         NaN            NaN
# std      NaN         NaN            NaN
# min      NaN         NaN            NaN
# 25%      NaN         NaN            NaN
# 50%      NaN         NaN            NaN
# 75%      NaN         NaN            NaN
# max      NaN         NaN            NaN
#
#                                               Description  Weight (kg)  \
# count                                                  67    67.000000
# unique                                                 67          NaN
# top     The Abyssinian is easy to care for, and a joy ...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     4.708955
# std                                                   NaN     1.066534
# min                                                   NaN     3.000000
# 25%                                                   NaN     4.000000
# 50%                                                   NaN     4.500000
# 75%                                                   NaN     5.500000
# max                                                   NaN     7.500000
#
#         Life Span (years)                                 temperament  \
# count           67.000000                                          67
# unique                NaN                                          66
# top                   NaN  Affectionate, Intelligent, Playful, Social
# freq                  NaN                                           2
# mean            13.746269                                         NaN
# std              1.584425                                         NaN
# min             10.500000                                         NaN
# 25%             13.000000                                         NaN
# 50%             13.500000                                         NaN
# 75%             14.500000                                         NaN
# max             19.000000                                         NaN
#
#                                               Image URL
# count                                                65
# unique                                               65
# top     https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
# freq                                                  1
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN

# %%
sorted_origin = df.groupby('Origin')['Origin'].count().sort_values()

countries = sorted_origin.index
values = sorted_origin.values
plt.bar(countries, values)
plt.xlabel('Countries')
plt.ylabel('Cats breeds')
plt.title('Cats breeds per country')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.savefig('cats-breed.png')
plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(values, labels = countries, autopct= '%1.0f', rotatelabels=True)
plt.show()

# %%
# pd.set_option('display.max_rows', 67)

# %%
df[['Name', 'Image URL']]
# Out:
#                     Name                                         Image URL
# 0             Abyssinian   https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
# 1                 Aegean   https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg
# 2       American Bobtail   https://cdn2.thecatapi.com/images/hBXicehMA.jpg
# 3          American Curl   https://cdn2.thecatapi.com/images/xnsqonbjW.jpg
# 4     American Shorthair   https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg
# 5      American Wirehair   https://cdn2.thecatapi.com/images/8D--jCd21.jpg
# 6            Arabian Mau   https://cdn2.thecatapi.com/images/k71ULYfRr.jpg
# 7        Australian Mist   https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg
# 8               Balinese   https://cdn2.thecatapi.com/images/13MkvUreZ.jpg
# 9                Bambino   https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg
# 10                Bengal   https://cdn2.thecatapi.com/images/O3btzLlsO.jpg
# 11                Birman   https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg
# 12                Bombay   https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg
# 13      British Longhair   https://cdn2.thecatapi.com/images/7isAO4Cav.jpg
# 14     British Shorthair   https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg
# 15               Burmese   https://cdn2.thecatapi.com/images/4lXnnfxac.jpg
# 16              Burmilla   https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg
# 17   California Spangled   https://cdn2.thecatapi.com/images/B1ERTmgph.jpg
# 18     Chantilly-Tiffany   https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg
# 19             Chartreux   https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg
# 20               Chausie   https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg
# 21               Cheetoh   https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg
# 22  Colorpoint Shorthair   https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg
# 23           Cornish Rex   https://cdn2.thecatapi.com/images/unX21IBVB.jpg
# 24                Cymric   https://cdn2.thecatapi.com/images/3dbtapCWM.jpg
# 25                Cyprus   https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg
# 26             Devon Rex   https://cdn2.thecatapi.com/images/4RzEwvyzz.jpg
# 27               Donskoy   https://cdn2.thecatapi.com/images/3KG57GfMW.jpg
# 28             Dragon Li   https://cdn2.thecatapi.com/images/BQMSld0A0.jpg
# 29          Egyptian Mau   https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg
# 30      European Burmese                                               NaN
# 31      Exotic Shorthair   https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg
# 32          Havana Brown   https://cdn2.thecatapi.com/images/njK25knLH.jpg
# 33             Himalayan   https://cdn2.thecatapi.com/images/CDhOtM-Ig.jpg
# 34      Japanese Bobtail   https://cdn2.thecatapi.com/images/-tm9-znzl.jpg
# 35              Javanese   https://cdn2.thecatapi.com/images/xoI_EpOKe.jpg
# 36            Khao Manee   https://cdn2.thecatapi.com/images/165ok6ESN.jpg
# 37                 Korat   https://cdn2.thecatapi.com/images/DbwiefiaY.jpg
# 38              Kurilian  https://cdn2.thecatapi.com/images/NZpO4pU56M.jpg
# 39                LaPerm   https://cdn2.thecatapi.com/images/aKbsEYjSl.jpg
# 40            Maine Coon   https://cdn2.thecatapi.com/images/OOD3VXAQn.jpg
# 41               Malayan                                               NaN
# 42                  Manx   https://cdn2.thecatapi.com/images/fhYh2PDcC.jpg
# 43              Munchkin   https://cdn2.thecatapi.com/images/j5cVSqLer.jpg
# 44              Nebelung   https://cdn2.thecatapi.com/images/OGTWqNNOt.jpg
# 45  Norwegian Forest Cat   https://cdn2.thecatapi.com/images/06dgGmEOV.jpg
# 46                Ocicat   https://cdn2.thecatapi.com/images/JAx-08Y0n.jpg
# 47              Oriental   https://cdn2.thecatapi.com/images/LutjkZJpH.jpg
# 48               Persian   https://cdn2.thecatapi.com/images/-Zfz5z2jK.jpg
# 49             Pixie-bob   https://cdn2.thecatapi.com/images/z7fJRNeN6.jpg
# 50            Ragamuffin   https://cdn2.thecatapi.com/images/SMuZx-bFM.jpg
# 51               Ragdoll   https://cdn2.thecatapi.com/images/oGefY4YoG.jpg
# 52          Russian Blue   https://cdn2.thecatapi.com/images/Rhj-JsTLP.jpg
# 53              Savannah   https://cdn2.thecatapi.com/images/a8nIYvs6S.jpg
# 54         Scottish Fold   https://cdn2.thecatapi.com/images/o9t0LDcsa.jpg
# 55           Selkirk Rex   https://cdn2.thecatapi.com/images/II9dOZmrw.jpg
# 56               Siamese   https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg
# 57              Siberian   https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg
# 58             Singapura   https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg
# 59              Snowshoe   https://cdn2.thecatapi.com/images/MK-sYESvO.jpg
# 60                Somali   https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg
# 61                Sphynx   https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg
# 62             Tonkinese   https://cdn2.thecatapi.com/images/KBroiVNCM.jpg
# 63                Toyger   https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg
# 64        Turkish Angora   https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg
# 65           Turkish Van   https://cdn2.thecatapi.com/images/sxIXJax6h.jpg
# 66        York Chocolate   https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg

# %%
df[df['Image URL'].isnull()]
# Out:
#       ID              Name          Origin  \
# 30  ebur  European Burmese           Burma
# 41  mala           Malayan  United Kingdom
#
#                                           Description  Weight (kg)  \
# 30  The European Burmese is a very affectionate, i...          4.5
# 41  Malayans love to explore and even enjoy travel...          4.5
#
#     Life Span (years)                                 temperament Image URL
# 30               12.5                  Sweet, Affectionate, Loyal       NaN
# 41               15.0  Affectionate, Interactive, Playful, Social       NaN

# %%
df
# Out:
#       ID                  Name                Origin  \
# 0   abys            Abyssinian                 Egypt
# 1   aege                Aegean                Greece
# 2   abob      American Bobtail         United States
# 3   acur         American Curl         United States
# 4   asho    American Shorthair         United States
# 5   awir     American Wirehair         United States
# 6   amau           Arabian Mau  United Arab Emirates
# 7   amis       Australian Mist             Australia
# 8   bali              Balinese         United States
# 9   bamb               Bambino         United States
# 10  beng                Bengal         United States
# 11  birm                Birman                France
# 12  bomb                Bombay         United States
# 13  bslo      British Longhair        United Kingdom
# 14  bsho     British Shorthair        United Kingdom
# 15  bure               Burmese                 Burma
# 16  buri              Burmilla        United Kingdom
# 17  cspa   California Spangled         United States
# 18  ctif     Chantilly-Tiffany         United States
# 19  char             Chartreux                France
# 20  chau               Chausie                 Egypt
# 21  chee               Cheetoh         United States
# 22  csho  Colorpoint Shorthair         United States
# 23  crex           Cornish Rex        United Kingdom
# 24  cymr                Cymric                Canada
# 25  cypr                Cyprus                Cyprus
# 26  drex             Devon Rex        United Kingdom
# 27  dons               Donskoy                Russia
# 28  lihu             Dragon Li                 China
# 29  emau          Egyptian Mau                 Egypt
# 30  ebur      European Burmese                 Burma
# 31  esho      Exotic Shorthair         United States
# 32  hbro          Havana Brown        United Kingdom
# 33  hima             Himalayan         United States
# 34  jbob      Japanese Bobtail                 Japan
# 35  java              Javanese         United States
# 36  khao            Khao Manee              Thailand
# 37  kora                 Korat              Thailand
# 38  kuri              Kurilian                Russia
# 39  lape                LaPerm              Thailand
# 40  mcoo            Maine Coon         United States
# 41  mala               Malayan        United Kingdom
# 42  manx                  Manx           Isle of Man
# 43  munc              Munchkin         United States
# 44  nebe              Nebelung         United States
# 45  norw  Norwegian Forest Cat                Norway
# 46  ocic                Ocicat         United States
# 47  orie              Oriental         United States
# 48  pers               Persian         Iran (Persia)
# 49  pixi             Pixie-bob         United States
# 50  raga            Ragamuffin         United States
# 51  ragd               Ragdoll         United States
# 52  rblu          Russian Blue                Russia
# 53  sava              Savannah         United States
# 54  sfol         Scottish Fold        United Kingdom
# 55  srex           Selkirk Rex         United States
# 56  siam               Siamese              Thailand
# 57  sibe              Siberian                Russia
# 58  sing             Singapura             Singapore
# 59  snow              Snowshoe         United States
# 60  soma                Somali               Somalia
# 61  sphy                Sphynx                Canada
# 62  tonk             Tonkinese                Canada
# 63  toyg                Toyger         United States
# 64  tang        Turkish Angora                Turkey
# 65  tvan           Turkish Van                Turkey
# 66  ycho        York Chocolate         United States
#
#                                           Description  Weight (kg)  \
# 0   The Abyssinian is easy to care for, and a joy ...          4.0
# 1   Native to the Greek islands known as the Cycla...          4.0
# 2   American Bobtails are loving and incredibly in...          5.0
# 3   Distinguished by truly unique ears that curl b...          3.5
# 4   The American Shorthair is known for its longev...          5.5
# 5   The American Wirehair tends to be a calm and t...          5.5
# 6   Arabian Mau cats are social and energetic. Due...          5.5
# 7   The Australian Mist thrives on human companion...          5.0
# 8   Balinese are curious, outgoing, intelligent ca...          3.5
# 9   The Bambino is a breed of cat that was created...          3.0
# 10  Bengals are a lot of fun to live with, but the...          5.0
# 11  The Birman is a docile, quiet cat who loves pe...          5.0
# 12  The the golden eyes and the shiny black coa of...          4.0
# 13  The British Longhair is a very laid-back relax...          6.0
# 14  The British Shorthair is a very pleasant cat t...          7.0
# 15  Burmese love being with people, playing with t...          4.0
# 16  The Burmilla is a fairly placid cat. She tends...          4.5
# 17  Perhaps the only thing about the California sp...          6.0
# 18  The Chantilly is a devoted companion and prefe...          4.0
# 19  The Chartreux is generally silent but communic...          5.0
# 20  For those owners who desire a feline capable o...          5.0
# 21  The Cheetoh has a super affectionate nature an...          5.5
# 22  Colorpoint Shorthairs are an affectionate bree...          3.5
# 23  This is a confident cat who loves people and w...          3.0
# 24  The Cymric is a placid, sweet cat. They do not...          5.0
# 25  Loving, loyal, social and inquisitive, the Cyp...          5.5
# 26  The favourite perch of the Devon Rex is right ...          3.5
# 27  Donskoy are affectionate, intelligent, and eas...          5.5
# 28  The Dragon Li is loyal, but not particularly a...          5.0
# 29  The Egyptian Mau is gentle and reserved. She l...          4.5
# 30  The European Burmese is a very affectionate, i...          4.5
# 31  The Exotic Shorthair is a gentle friendly cat ...          4.5
# 32  The Havana Brown is human oriented, playful, a...          4.0
# 33  Calm and devoted, Himalayans make excellent co...          4.5
# 34  The Japanese Bobtail is an active, sweet, lovi...          3.5
# 35  Javanese are endlessly interested, intelligent...          3.5
# 36  The Khao Manee is highly intelligent, with an ...          5.0
# 37  The Korat is a natural breed, and one of the o...          4.0
# 38  The character of the Kurilian Bobtail is indep...          5.5
# 39  LaPerms are gentle and affectionate but also v...          4.0
# 40  They are known for their size and luxurious lo...          6.5
# 41  Malayans love to explore and even enjoy travel...          4.5
# 42  The Manx is a placid, sweet cat that is gentle...          4.5
# 43  The Munchkin is an outgoing cat who enjoys bei...          3.0
# 44  The Nebelung may have a reserved nature, but s...          4.0
# 45  The Norwegian Forest Cat is a sweet, loving ca...          5.5
# 46  Loyal and devoted to their owners, the Ocicat ...          5.0
# 47  Orientals are passionate about the people in t...          3.5
# 48  Persians are sweet, gentle cats that can be pl...          5.0
# 49  Companionable and affectionate, the Pixie-bob ...          6.0
# 50  The Ragamuffin is calm, even tempered and gets...          6.5
# 51  Ragdolls love their people, greeting them at t...          7.0
# 52  Russian Blues are very loving and reserved. Th...          3.5
# 53  Savannah is the feline version of a dog. Activ...          7.5
# 54  The Scottish Fold is a sweet, charming breed. ...          3.5
# 55  The Selkirk Rex is an incredibly patient, lovi...          5.0
# 56  While Siamese cats are extremely fond of their...          5.5
# 57  The Siberians dog like temperament and affecti...          5.5
# 58  The Singapura is usually cautious when it come...          3.0
# 59  The Snowshoe is a vibrant, energetic, affectio...          4.0
# 60  The Somali lives life to the fullest. He climb...          4.0
# 61  The Sphynx is an intelligent, inquisitive, ext...          4.0
# 62  Intelligent and generous with their affection,...          4.0
# 63  The Toyger has a sweet, calm personality and i...          5.0
# 64  This is a smart and intelligent cat which bond...          3.5
# 65  While the Turkish Van loves to jump and climb,...          6.0
# 66  York Chocolate cats are known to be true lap c...          6.5
#
#     Life Span (years)                                        temperament  \
# 0                14.5  Active, Energetic, Independent, Intelligent, G...
# 1                10.5  Affectionate, Social, Intelligent, Playful, Ac...
# 2                13.0  Intelligent, Interactive, Lively, Playful, Sen...
# 3                14.0  Affectionate, Curious, Intelligent, Interactiv...
# 4                16.0         Active, Curious, Easy Going, Playful, Calm
# 5                16.0  Affectionate, Curious, Gentle, Intelligent, In...
# 6                13.0  Affectionate, Agile, Curious, Independent, Pla...
# 7                14.0  Lively, Social, Fun-loving, Relaxed, Affectionate
# 8                12.5                 Affectionate, Intelligent, Playful
# 9                13.0        Affectionate, Lively, Friendly, Intelligent
# 10               13.5    Alert, Agile, Energetic, Demanding, Intelligent
# 11               14.5               Affectionate, Active, Gentle, Social
# 12               14.0  Affectionate, Dependent, Gentle, Intelligent, ...
# 13               13.0  Affectionate, Easy Going, Independent, Intelli...
# 14               14.5  Affectionate, Easy Going, Gentle, Loyal, Patie...
# 15               15.5  Curious, Intelligent, Gentle, Social, Interact...
# 16               12.5  Easy Going, Friendly, Intelligent, Lively, Pla...
# 17               12.0  Affectionate, Curious, Intelligent, Loyal, Social
# 18               15.0        Affectionate, Demanding, Interactive, Loyal
# 19               13.5  Affectionate, Loyal, Intelligent, Social, Live...
# 20               13.0         Affectionate, Intelligent, Playful, Social
# 21               13.0          Affectionate, Gentle, Intelligent, Social
# 22               14.0         Affectionate, Intelligent, Playful, Social
# 23               12.5  Affectionate, Intelligent, Active, Curious, Pl...
# 24               11.0                Gentle, Loyal, Intelligent, Playful
# 25               13.5                               Affectionate, Social
# 26               12.5  Highly interactive, Mischievous, Loyal, Social...
# 27               13.5               Playful, affectionate, loyal, social
# 28               13.5       Intelligent, Friendly, Gentle, Loving, Loyal
# 29               19.0  Agile, Dependent, Gentle, Intelligent, Lively,...
# 30               12.5                         Sweet, Affectionate, Loyal
# 31               13.5        Affectionate, Sweet, Loyal, Quiet, Peaceful
# 32               12.5  Affectionate, Curious, Demanding, Friendly, In...
# 33               12.0      Dependent, Gentle, Intelligent, Quiet, Social
# 34               15.0  Active, Agile, Clever, Easy Going, Intelligent...
# 35               11.0              Active, Devoted, Intelligent, Playful
# 36               11.0            Calm, Relaxed, Talkative, Playful, Warm
# 37               12.5  Active, Loyal, highly intelligent, Expressive,...
# 38               17.5  Independent, highly intelligent, clever, inqui...
# 39               12.5  Affectionate, Friendly, Gentle, Intelligent, P...
# 40               13.5  Adaptable, Intelligent, Loving, Gentle, Indepe...
# 41               15.0         Affectionate, Interactive, Playful, Social
# 42               13.0    Easy Going, Intelligent, Loyal, Playful, Social
# 43               12.5            Agile, Easy Going, Intelligent, Playful
# 44               13.5                        Gentle, Quiet, Shy, Playful
# 45               14.0  Sweet, Active, Intelligent, Social, Playful, L...
# 46               13.0  Active, Agile, Curious, Demanding, Friendly, G...
# 47               13.0  Energetic, Affectionate, Intelligent, Social, ...
# 48               14.5                 Affectionate, loyal, Sedate, Quiet
# 49               14.5           Affectionate, Social, Intelligent, Loyal
# 50               14.0               Affectionate, Friendly, Gentle, Calm
# 51               14.5   Affectionate, Friendly, Gentle, Quiet, Easygoing
# 52               13.0  Active, Dependent, Easy Going, Gentle, Intelli...
# 53               18.5  Curious, Social, Intelligent, Loyal, Outgoing,...
# 54               12.5  Affectionate, Intelligent, Loyal, Playful, Soc...
# 55               14.5  Active, Affectionate, Dependent, Gentle, Patie...
# 56               13.5  Active, Agile, Clever, Sociable, Loving, Energ...
# 57               13.5  Curious, Intelligent, Loyal, Sweet, Agile, Pla...
# 58               13.5  Affectionate, Curious, Easy Going, Intelligent...
# 59               16.5  Affectionate, Social, Intelligent, Sweet-tempered
# 60               14.0  Mischievous, Tenacious, Intelligent, Affection...
# 61               13.0        Loyal, Inquisitive, Friendly, Quiet, Gentle
# 62               15.0  Curious, Intelligent, Social, Lively, Outgoing...
# 63               13.5                       Playful, Social, Intelligent
# 64               16.5  Affectionate, Agile, Clever, Gentle, Intellige...
# 65               14.5      Agile, Intelligent, Loyal, Playful, Energetic
# 66               14.0    Playful, Social, Intelligent, Curious, Friendly
#
#                                            Image URL
# 0    https://cdn2.thecatapi.com/images/0XYvRd7oD.jpg
# 1    https://cdn2.thecatapi.com/images/ozEvzdVM-.jpg
# 2    https://cdn2.thecatapi.com/images/hBXicehMA.jpg
# 3    https://cdn2.thecatapi.com/images/xnsqonbjW.jpg
# 4    https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg
# 5    https://cdn2.thecatapi.com/images/8D--jCd21.jpg
# 6    https://cdn2.thecatapi.com/images/k71ULYfRr.jpg
# 7    https://cdn2.thecatapi.com/images/_6x-3TiCA.jpg
# 8    https://cdn2.thecatapi.com/images/13MkvUreZ.jpg
# 9    https://cdn2.thecatapi.com/images/5AdhMjeEu.jpg
# 10   https://cdn2.thecatapi.com/images/O3btzLlsO.jpg
# 11   https://cdn2.thecatapi.com/images/HOrX5gwLS.jpg
# 12   https://cdn2.thecatapi.com/images/5iYq9NmT1.jpg
# 13   https://cdn2.thecatapi.com/images/7isAO4Cav.jpg
# 14   https://cdn2.thecatapi.com/images/s4wQfYoEk.jpg
# 15   https://cdn2.thecatapi.com/images/4lXnnfxac.jpg
# 16   https://cdn2.thecatapi.com/images/jvg3XfEdC.jpg
# 17   https://cdn2.thecatapi.com/images/B1ERTmgph.jpg
# 18   https://cdn2.thecatapi.com/images/TR-5nAd_S.jpg
# 19   https://cdn2.thecatapi.com/images/j6oFGLpRG.jpg
# 20   https://cdn2.thecatapi.com/images/vJ3lEYgXr.jpg
# 21   https://cdn2.thecatapi.com/images/IFXsxmXLm.jpg
# 22   https://cdn2.thecatapi.com/images/oSpqGyUDS.jpg
# 23   https://cdn2.thecatapi.com/images/unX21IBVB.jpg
# 24   https://cdn2.thecatapi.com/images/3dbtapCWM.jpg
# 25   https://cdn2.thecatapi.com/images/tJbzb7FKo.jpg
# 26   https://cdn2.thecatapi.com/images/4RzEwvyzz.jpg
# 27   https://cdn2.thecatapi.com/images/3KG57GfMW.jpg
# 28   https://cdn2.thecatapi.com/images/BQMSld0A0.jpg
# 29   https://cdn2.thecatapi.com/images/TuSyTkt2n.jpg
# 30                                               NaN
# 31   https://cdn2.thecatapi.com/images/YnPrYEmfe.jpg
# 32   https://cdn2.thecatapi.com/images/njK25knLH.jpg
# 33   https://cdn2.thecatapi.com/images/CDhOtM-Ig.jpg
# 34   https://cdn2.thecatapi.com/images/-tm9-znzl.jpg
# 35   https://cdn2.thecatapi.com/images/xoI_EpOKe.jpg
# 36   https://cdn2.thecatapi.com/images/165ok6ESN.jpg
# 37   https://cdn2.thecatapi.com/images/DbwiefiaY.jpg
# 38  https://cdn2.thecatapi.com/images/NZpO4pU56M.jpg
# 39   https://cdn2.thecatapi.com/images/aKbsEYjSl.jpg
# 40   https://cdn2.thecatapi.com/images/OOD3VXAQn.jpg
# 41                                               NaN
# 42   https://cdn2.thecatapi.com/images/fhYh2PDcC.jpg
# 43   https://cdn2.thecatapi.com/images/j5cVSqLer.jpg
# 44   https://cdn2.thecatapi.com/images/OGTWqNNOt.jpg
# 45   https://cdn2.thecatapi.com/images/06dgGmEOV.jpg
# 46   https://cdn2.thecatapi.com/images/JAx-08Y0n.jpg
# 47   https://cdn2.thecatapi.com/images/LutjkZJpH.jpg
# 48   https://cdn2.thecatapi.com/images/-Zfz5z2jK.jpg
# 49   https://cdn2.thecatapi.com/images/z7fJRNeN6.jpg
# 50   https://cdn2.thecatapi.com/images/SMuZx-bFM.jpg
# 51   https://cdn2.thecatapi.com/images/oGefY4YoG.jpg
# 52   https://cdn2.thecatapi.com/images/Rhj-JsTLP.jpg
# 53   https://cdn2.thecatapi.com/images/a8nIYvs6S.jpg
# 54   https://cdn2.thecatapi.com/images/o9t0LDcsa.jpg
# 55   https://cdn2.thecatapi.com/images/II9dOZmrw.jpg
# 56   https://cdn2.thecatapi.com/images/ai6Jps4sx.jpg
# 57   https://cdn2.thecatapi.com/images/3bkZAjRh1.jpg
# 58   https://cdn2.thecatapi.com/images/Qtncp2nRe.jpg
# 59   https://cdn2.thecatapi.com/images/MK-sYESvO.jpg
# 60   https://cdn2.thecatapi.com/images/EPF2ejNS0.jpg
# 61   https://cdn2.thecatapi.com/images/BDb8ZXb1v.jpg
# 62   https://cdn2.thecatapi.com/images/KBroiVNCM.jpg
# 63   https://cdn2.thecatapi.com/images/O3F3_S1XN.jpg
# 64   https://cdn2.thecatapi.com/images/7CGV6WVXq.jpg
# 65   https://cdn2.thecatapi.com/images/sxIXJax6h.jpg
# 66   https://cdn2.thecatapi.com/images/0SxW2SQ_S.jpg

# %%
df[(df['Origin'] == 'United States') & (df['Life Span (years)'] > 15)]
# Out:
#       ID                Name         Origin  \
# 4   asho  American Shorthair  United States
# 5   awir   American Wirehair  United States
# 53  sava            Savannah  United States
# 59  snow            Snowshoe  United States
#
#                                           Description  Weight (kg)  \
# 4   The American Shorthair is known for its longev...          5.5
# 5   The American Wirehair tends to be a calm and t...          5.5
# 53  Savannah is the feline version of a dog. Activ...          7.5
# 59  The Snowshoe is a vibrant, energetic, affectio...          4.0
#
#     Life Span (years)                                        temperament  \
# 4                16.0         Active, Curious, Easy Going, Playful, Calm
# 5                16.0  Affectionate, Curious, Gentle, Intelligent, In...
# 53               18.5  Curious, Social, Intelligent, Loyal, Outgoing,...
# 59               16.5  Affectionate, Social, Intelligent, Sweet-tempered
#
#                                           Image URL
# 4   https://cdn2.thecatapi.com/images/JFPROfGtQ.jpg
# 5   https://cdn2.thecatapi.com/images/8D--jCd21.jpg
# 53  https://cdn2.thecatapi.com/images/a8nIYvs6S.jpg
# 59  https://cdn2.thecatapi.com/images/MK-sYESvO.jpg

# %%
df[['Weight (kg)', 'Life Span (years)']].corr()
# Out:
#                    Weight (kg)  Life Span (years)
# Weight (kg)           1.000000           0.256006
# Life Span (years)     0.256006           1.000000

# %%
weight = df['Weight (kg)']
life_span =df['Life Span (years)']

plt.scatter(weight, life_span)
plt.show()
